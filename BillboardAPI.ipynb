# %%
import pandas as pd
import requests
import json
import pandas as pd
import os
from bs4 import BeautifulSoup

# %%
import requests

url = "https://billboard-api2.p.rapidapi.com/artist-100"

querystring = {"date":"2023-05-25","range":"1-10"}

headers = {
	"X-RapidAPI-Key": "5c0456e21emsh44f3ac51efb5c7ap1cbb79jsn944f91094df6",
	"X-RapidAPI-Host": "billboard-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'info': {'category': 'Billboard', 'chart': 'ARTIST 100', 'date': '2023-05-27', 'source': 'Billboard-API'}, 'content': {'1': {'rank': '1', 'artist': 'Taylor Swift', 'weeks at no.1': '1', 'last week': '2', 'peak position': '1', 'weeks on chart': '460', 'detail': 'up'}, '2': {'rank': '2', 'artist': 'Morgan Wallen', 'last week': '3', 'peak position': '1', 'weeks on chart': '219', 'detail': 'up'}, '3': {'rank': '3', 'artist': 'Ed Sheeran', 'last week': '1', 'peak position': '1', 'weeks on chart': '457', 'detail': 'down'}, '4': {'rank': '4', 'artist': 'Luke Combs', 'last week': '4', 'peak position': '1', 'weeks on chart': '324', 'detail': 'same'}, '5': {'rank': '5', 'artist': 'Jonas Brothers', 'last week': 'None', 'peak position': '1', 'weeks on chart': '117', 'detail': 're-entry'}, '6': {'rank': '6', 'artist': 'SZA', 'last week': '5', 'peak position': '1', 'weeks on chart': '194', 'detail': 'down'}, '7': {'rank': '7', 'artist': 'Daft Punk', 'last week': 'None', 'peak position': '7', 'wee
# ...

# %%
r = response.json()

# %%
billboard_df = pd.DataFrame(r['content'])
billboard_df
# Out:
#                            1              2           3           4  \
# rank                       1              2           3           4
# artist          Taylor Swift  Morgan Wallen  Ed Sheeran  Luke Combs
# weeks at no.1              1            NaN         NaN         NaN
# last week                  2              3           1           4
# peak position              1              1           1           1
# weeks on chart           460            219         457         324
# detail                    up             up        down        same
#
#                              5     6          7           8      9  \
# rank                         5     6          7           8      9
# artist          Jonas Brothers   SZA  Daft Punk  The Weeknd  Drake
# weeks at no.1              NaN   NaN        NaN         NaN    NaN
# last week                 None     5       None          10      7
# peak position                1     1          7           1      1
# ...

# %%
url = "https://billboard-api2.p.rapidapi.com/artist-100"

querystring = {"date":"2022-05-25","range":"1-10"}

headers = {
	"X-RapidAPI-Key": "5c0456e21emsh44f3ac51efb5c7ap1cbb79jsn944f91094df6",
	"X-RapidAPI-Host": "billboard-api2.p.rapidapi.com"
}

response2 = requests.get(url, headers=headers, params=querystring)

r2 = response2.json()

billboard_df2 = pd.DataFrame(r2['content'])
billboard_df2
# Out:
#                              1          2                    3              4  \
# rank                         1          2                    3              4
# artist          Kendrick Lamar  Bad Bunny  TOMORROW X TOGETHER  Morgan Wallen
# weeks at no.1                1        NaN                  NaN            NaN
# last week                    9          1                 None              4
# peak position                1          1                    3              1
# weeks on chart             333        216                   20            167
# detail                      up       down             re-entry           same
#
#                                      5       6            7         8  \
# rank                                 5       6            7         8
# artist          Florence + The Machine  Future  Jack Harlow  Doja Cat
# weeks at no.1                      NaN     NaN          NaN       NaN
# ...

# %%
url = "https://billboard-api2.p.rapidapi.com/artist-100"

querystring = {"date":"2021-05-25","range":"1-10"}

headers = {
	"X-RapidAPI-Key": "5c0456e21emsh44f3ac51efb5c7ap1cbb79jsn944f91094df6",
	"X-RapidAPI-Host": "billboard-api2.p.rapidapi.com"
}

response3 = requests.get(url, headers=headers, params=querystring)

r3 = response3.json()

billboard_df3 = pd.DataFrame(r3['content'])
billboard_df3
# Out:
#                       1               2         3      4            5  \
# rank                  1               2         3      4            5
# artist          J. Cole  Olivia Rodrigo  Dua Lipa  Drake  Nicki Minaj
# last week            12              21         1      9            -
# peak position         1               2         1      1            2
# weeks on chart      230              19       159    360          257
# detail               up              up      down     up     re-entry
#
#                          6              7               8             9  \
# rank                     6              7               8             9
# artist          The Weeknd  Ariana Grande  The Black Keys  Alan Jackson
# last week                3              2               -             -
# peak position            1              1               5             9
# weeks on chart         306            328               9            36
# ...

# %%
url = "https://billboard-api2.p.rapidapi.com/artist-100"

querystring = {"date":"2020-05-25","range":"1-10"}

headers = {
	"X-RapidAPI-Key": "5c0456e21emsh44f3ac51efb5c7ap1cbb79jsn944f91094df6",
	"X-RapidAPI-Host": "billboard-api2.p.rapidapi.com"
}

response4 = requests.get(url, headers=headers, params=querystring)

r4 = response4.json()

billboard_df4 = pd.DataFrame(r4['content'])
billboard_df4
# Out:
#                      1         2      3                              4  \
# rank                 1         2      3                              4
# artist          Future    Polo G  Drake  Jason Isbell And The 400 Unit
# last week           38         -      2                             67
# peak position        1         2      1                              4
# weeks on chart     180        19    308                              2
# detail              up  re-entry   down                             up
#
#                          5           6             7            8       9  \
# rank                     5           6             7            8       9
# artist          The Weeknd  Luke Combs  Harry Styles  Post Malone  DaBaby
# last week                5           8            20            9      10
# peak position            1           1             1            1       1
# weeks on chart         254         168            47          204      58
# ...

# %%
url = "https://billboard-api2.p.rapidapi.com/artist-100"

querystring = {"date":"2019-05-25","range":"1-10"}

headers = {
	"X-RapidAPI-Key": "5c0456e21emsh44f3ac51efb5c7ap1cbb79jsn944f91094df6",
	"X-RapidAPI-Host": "billboard-api2.p.rapidapi.com"
}

response5 = requests.get(url, headers=headers, params=querystring)


r5= response5.json()

billboard_df5 = pd.DataFrame(r5['content'])
billboard_df5
# Out:
#                   1              2       3            4              5     6  \
# rank              1              2       3            4              5     6
# artist          BTS  Billie Eilish  Khalid  Post Malone  Ariana Grande  P!nk
# last week         2              5       6            8              7     1
# peak position     1              1       1            1              1     1
# weeks on chart  136             38     115          151            223   152
# detail           up             up      up           up             up  down
#
#                          7          8           9           10
# rank                     7          8           9           10
# artist          Ed Sheeran  Lil Nas X  Luke Combs  Sammy Hagar
# last week               31          9          16            -
# peak position            1          3           5           10
# weeks on chart         249          9         115            1
# ...

# %%
r
# Out:
# {'info': {'category': 'Billboard',
#   'chart': 'ARTIST 100',
#   'date': '2023-05-27',
#   'source': 'Billboard-API'},
#  'content': {'1': {'rank': '1',
#    'artist': 'Taylor Swift',
#    'weeks at no.1': '1',
#    'last week': '2',
#    'peak position': '1',
#    'weeks on chart': '460',
#    'detail': 'up'},
#   '2': {'rank': '2',
#    'artist': 'Morgan Wallen',
#    'last week': '3',
#    'peak position': '1',
#    'weeks on chart': '219',
#    'detail': 'up'},
#   '3': {'rank': '3',
#    'artist': 'Ed Sheeran',
#    'last week': '1',
#    'peak position': '1',
#    'weeks on chart': '457',
#    'detail': 'down'},
#   '4': {'rank': '4',
#    'artist': 'Luke Combs',
#    'last week': '4',
#    'peak position': '1',
#    'weeks on chart': '324',
#    'detail': 'same'},
#   '5': {'rank': '5',
#    'artist': 'Jonas Brothers',
#    'last week': 'None',
#    'peak position': '1',
#    'weeks on chart': '117',
#    'detail': 're-entry'},
#   '6': {'rank': '6',
#    'artist': 'SZA',
# ...

# %%
rdf = pd.DataFrame(r)
rdf
# Out:
#                    info                                            content
# category      Billboard                                                NaN
# chart        ARTIST 100                                                NaN
# date         2023-05-27                                                NaN
# source    Billboard-API                                                NaN
# 1                   NaN  {'rank': '1', 'artist': 'Taylor Swift', 'weeks...
# 2                   NaN  {'rank': '2', 'artist': 'Morgan Wallen', 'last...
# 3                   NaN  {'rank': '3', 'artist': 'Ed Sheeran', 'last we...
# 4                   NaN  {'rank': '4', 'artist': 'Luke Combs', 'last we...
# 5                   NaN  {'rank': '5', 'artist': 'Jonas Brothers', 'las...
# 6                   NaN  {'rank': '6', 'artist': 'SZA', 'last week': '5...
# 7                   NaN  {'rank': '7', 'artist': 'Daft Punk', 'last wee...
# ...

# %%
import requests

url = "https://billboard-api2.p.rapidapi.com/year-end-chart/top-artists"

querystring = {"year":"2022"}

headers = {
	"X-RapidAPI-Key": "5c0456e21emsh44f3ac51efb5c7ap1cbb79jsn944f91094df6",
	"X-RapidAPI-Host": "billboard-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'notice': 'This endpoint is available on the Pro plan and above. If you want to access this endpoint, please upgrade your plan.'}

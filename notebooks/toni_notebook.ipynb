# %%
import requests
import json
import pandas as pd
import os
from bs4 import BeautifulSoup

# %%
CLIENT_ID = 'b850dcd85a384ec8b4c611ca9c04a4c3'
CLIENT_SECRET = '9c1143f81e4e446cb90eb80f8a37f949'

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '01TyFEZu6mHbffsVfxgrFn'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)

# %%
def search_artists(artist_name):
    headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}
    params = {'q': artist_name, 'type': 'artist', 'limit': 1}
    search_url = BASE_URL + 'search'
    response = requests.get(search_url, headers=headers, params=params)
    data = response.json()
    artist_ids = []
    for artist in data['artists']['items']:
        artist_ids.append(artist['id'])
    return artist_ids

# %%
search_artists('rihanna')
# Out:
# ['5pKCCKE2ajJHZ9KAiaK11H']

# %%
import datetime
import billboard
import pandas as pd
from collections import defaultdict

# Initiate the dictionary to store artist data
artist_data = defaultdict(int)

# Set the date for 5 years ago
date = datetime.datetime.now() - datetime.timedelta(weeks=20)

# Loop over each week for the past 5 years
while date < datetime.datetime.now():
    # Fetch the top 100 songs for this week
    chart = billboard.ChartData('hot-100', date=date.strftime('%Y-%m-%d'))

    # Loop over each song in the chart
    for song in chart:
        # Loop over each artist for the song (songs can have multiple artists)
        for artist in song.artist.split(' Featuring '):
            # Increment the number of weeks this artist has been in the top 100
            artist_data[artist] += 1

    # Increment the date by one week
    date += datetime.timedelta(weeks=1)

# %%
# Convert the artist data into a DataFrame
df = pd.DataFrame(list(artist_data.items()), columns=['Artist', 'WeeksInTop100'])

# Sort the DataFrame by the number of weeks in the top 100
df = df.sort_values('WeeksInTop100', ascending=False)

# Print the top 10 artists
print(df.head(10))
# Out:
#                 Artist  WeeksInTop100
# 42       Morgan Wallen            225
# 10                 SZA            145
# 61          Luke Combs             61
# 7         Taylor Swift             54
# 19   Drake & 21 Savage             53
# 100           Lil Baby             47
# 60       Lainey Wilson             35
# 38          Zach Bryan             35
# 47        Lil Uzi Vert             27
# 54    Bailey Zimmerman             26

# %%
import datetime
import billboard
import pandas as pd
from collections import defaultdict

# Initiate the dictionary to store artist data
artist_data = defaultdict(int)

# Set the date for 5 years ago
date = datetime.datetime.now() - datetime.timedelta(weeks=5*52)

# Loop over each week for the past 5 years
while date < datetime.datetime.now():
    # Fetch the top 100 songs for this week
    chart = billboard.ChartData('hot-100', date=date.strftime('%Y-%m-%d'))

    # Loop over each song in the chart
    for song in chart:
        # Loop over each artist for the song (songs can have multiple artists)
        for artist in song.artist.split(' Featuring '):
            # Increment the number of weeks this artist has been in the top 100
            artist_data[artist] += 1

    # Increment the date by one week
    date += datetime.timedelta(weeks=1)

# Convert the artist data into a DataFrame
df = pd.DataFrame(list(artist_data.items()), columns=['Artist', 'Total Chart Entries Weekly for Past 5 years'])

# Sort the DataFrame by the number of weeks in the top 100
df = df.sort_values('Total Chart Entries Weekly for Past 5 years', ascending=False)

# Print the top 10 artists
print(df.head(10))
# Out:
#             Artist  Total Chart Entries Weekly for Past 5 years
# 0            Drake                                          841
# 54   Morgan Wallen                                          636
# 78        Lil Baby                                          500
# 33    Taylor Swift                                          421
# 2      Post Malone                                          377
# 37      Luke Combs                                          377
# 523       Doja Cat                                          376
# 367         DaBaby                                          337
# 397            SZA                                          309
# 178  Billie Eilish                                          281

# %%
topten_df = (df.head(10))

# %%
topten_df['Artist']
# Out:
# 0              Drake
# 54     Morgan Wallen
# 78          Lil Baby
# 33      Taylor Swift
# 2        Post Malone
# 37        Luke Combs
# 523         Doja Cat
# 367           DaBaby
# 397              SZA
# 178    Billie Eilish
# Name: Artist, dtype: object

# %%
topten_list = topten_df['Artist'].values.tolist()

# %%
topten_list
# Out:
# ['Drake',
#  'Morgan Wallen',
#  'Lil Baby',
#  'Taylor Swift',
#  'Post Malone',
#  'Luke Combs',
#  'Doja Cat',
#  'DaBaby',
#  'SZA',
#  'Billie Eilish']

# %%
artist_ids = []
for artist in topten_list:
    artist_ids += search_artists(artist)
print(artist_ids)
# Out:
# ['3TVXtAsR1Inumwj472S9r4', '4oUHIQIBe0LHzYfvXNW4QM', '5f7VJjfbwm532GiveGC0ZK', '06HL4z0CvFAxyc27GXpf02', '246dkjvS1zLTtiykXe5h60', '718COspgdWOnwOFpJHRZHS', '5cj0lLjcoR7YOSnhnX0Po5', '4r63FhuTkUYltbVAg5TQnk', '7tYKF4w9nC0nq9CsPZTHyP', '6qqNVTkY8uBg9cP3Jd7DAH']

# %%
artist_data = []
for artist in topten_list:
    artist_ids = search_artists(artist)
    for artist_id in artist_ids:
        artist_data.append({'name': artist, 'id': artist_id})
artist_df = pd.DataFrame(artist_data)
print(artist_df)
# Out:
#             name                      id
# 0          Drake  3TVXtAsR1Inumwj472S9r4
# 1  Morgan Wallen  4oUHIQIBe0LHzYfvXNW4QM
# 2       Lil Baby  5f7VJjfbwm532GiveGC0ZK
# 3   Taylor Swift  06HL4z0CvFAxyc27GXpf02
# 4    Post Malone  246dkjvS1zLTtiykXe5h60
# 5     Luke Combs  718COspgdWOnwOFpJHRZHS
# 6       Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 7         DaBaby  4r63FhuTkUYltbVAg5TQnk
# 8            SZA  7tYKF4w9nC0nq9CsPZTHyP
# 9  Billie Eilish  6qqNVTkY8uBg9cP3Jd7DAH

# %%
r = r.json()
r
# Out:
# {'danceability': 0.791,
#  'energy': 0.267,
#  'key': 5,
#  'loudness': -11.997,
#  'mode': 1,
#  'speechiness': 0.0415,
#  'acousticness': 0.674,
#  'instrumentalness': 0.534,
#  'liveness': 0.102,
#  'valence': 0.544,
#  'tempo': 165.99,
#  'type': 'audio_features',
#  'id': '01TyFEZu6mHbffsVfxgrFn',
#  'uri': 'spotify:track:01TyFEZu6mHbffsVfxgrFn',
#  'track_href': 'https://api.spotify.com/v1/tracks/01TyFEZu6mHbffsVfxgrFn',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/01TyFEZu6mHbffsVfxgrFn',
#  'duration_ms': 215111,
#  'time_signature': 4}

# %%
r
# Out:
# {'danceability': 0.791,
#  'energy': 0.267,
#  'key': 5,
#  'loudness': -11.997,
#  'mode': 1,
#  'speechiness': 0.0415,
#  'acousticness': 0.674,
#  'instrumentalness': 0.534,
#  'liveness': 0.102,
#  'valence': 0.544,
#  'tempo': 165.99,
#  'type': 'audio_features',
#  'id': '01TyFEZu6mHbffsVfxgrFn',
#  'uri': 'spotify:track:01TyFEZu6mHbffsVfxgrFn',
#  'track_href': 'https://api.spotify.com/v1/tracks/01TyFEZu6mHbffsVfxgrFn',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/01TyFEZu6mHbffsVfxgrFn',
#  'duration_ms': 215111,
#  'time_signature': 4}

# %%
artist_df
# Out:
#             name                      id
# 0          Drake  3TVXtAsR1Inumwj472S9r4
# 1  Morgan Wallen  4oUHIQIBe0LHzYfvXNW4QM
# 2       Lil Baby  5f7VJjfbwm532GiveGC0ZK
# 3   Taylor Swift  06HL4z0CvFAxyc27GXpf02
# 4    Post Malone  246dkjvS1zLTtiykXe5h60
# 5     Luke Combs  718COspgdWOnwOFpJHRZHS
# 6       Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 7         DaBaby  4r63FhuTkUYltbVAg5TQnk
# 8            SZA  7tYKF4w9nC0nq9CsPZTHyP
# 9  Billie Eilish  6qqNVTkY8uBg9cP3Jd7DAH

# %%
def artist_album(artist_id):
    albums = requests.get(BASE_URL + 'artists/' + artist_id + '/albums', 
                 headers=headers, 
                 params={'include_groups': 'album', 'limit': 50})
    d = albums.json()
    album_name = []
    for album in d['items']:
        album_name += (album['name'],)
    return album_name

# %%
artist_album('5pKCCKE2ajJHZ9KAiaK11H')
# Out:
# ['Black Panther: Wakanda Forever - Music From and Inspired By',
#  'ANTI (Deluxe)',
#  'ANTI (Deluxe)',
#  'ANTI',
#  'ANTI',
#  'Unapologetic (Deluxe Version)',
#  'Unapologetic (Deluxe Version)',
#  'Unapologetic (Deluxe)',
#  'Unapologetic (Deluxe)',
#  'Unapologetic',
#  'Unapologetic',
#  'Unapologetic (Deluxe)',
#  'Unapologetic (Edited Version)',
#  'Talk That Talk (Deluxe)',
#  'Talk That Talk (Deluxe)',
#  'Unapologetic (Deluxe Version [Edited])',
#  'Unapologetic (Standard Version [Edited])',
#  'Unapologetic (Edited Version)',
#  'Talk That Talk',
#  'Talk That Talk',
#  'Talk That Talk (Deluxe Explicit)',
#  'Talk That Talk (Deluxe Edited)',
#  'Talk That Talk (Explicit)',
#  'Talk That Talk (Edited)',
#  'Loud',
#  'Loud',
#  'Loud',
#  'Rated R: Remixed',
#  'Rated R: Remixed',
#  'Loud (Japan Version)',
#  'Rated R',
#  'Rated R',
#  'Rated R (International Explicit Nokia Exclusive Version)',
#  'Rated R',
#  'Good Girl Gone Bad: The Remixes',
#  'Good Girl Gone Bad: Reloaded',
#  'Good Girl Gone Bad: Reloaded',
#  'Good Girl Gone Bad: Reloaded',
#  'Good Girl Gone Bad (Deluxe)',
#  'Good Girl Gone Bad',
#  'Good Girl Gone Bad',
#  'A Girl Like Me',
#  'A Girl Like Me',
#  'A Girl Like Me',
#  'Music Of The Sun',
#  'Music Of The Sun']

# %%
artist_df["album"] = artist_df['id'].apply(artist_album)

# %%
artist_df
# Out:
#             name                      id  \
# 0          Drake  3TVXtAsR1Inumwj472S9r4
# 1  Morgan Wallen  4oUHIQIBe0LHzYfvXNW4QM
# 2       Lil Baby  5f7VJjfbwm532GiveGC0ZK
# 3   Taylor Swift  06HL4z0CvFAxyc27GXpf02
# 4    Post Malone  246dkjvS1zLTtiykXe5h60
# 5     Luke Combs  718COspgdWOnwOFpJHRZHS
# 6       Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 7         DaBaby  4r63FhuTkUYltbVAg5TQnk
# 8            SZA  7tYKF4w9nC0nq9CsPZTHyP
# 9  Billie Eilish  6qqNVTkY8uBg9cP3Jd7DAH
#
#                                                album
# 0  [Her Loss, Her Loss, Honestly, Nevermind, Hone...
# 1  [One Thing At A Time, One Thing At A Time, Dan...
# 2  [It's Only Me, It's Only Me, The Voice of the ...
# 3  [Midnights (The Til Dawn Edition), Midnights (...
# 4  [Twelve Carat Toothache (Deluxe), Twelve Carat...
# 5  [Gettin' Old, Growin' Up, What You See Ain't A...
# 6  [Planet Her (Deluxe), Planet Her (Deluxe), Pla...
# 7  [Baby On Baby 2, Baby On Baby 2, BETTER THAN Y...
# 8  [SOS, SOS, Ctrl (Deluxe), Dear Evan Hansen (Or...
# 9  [Happier Than Ever, Happier Than Ever, WHEN WE...

# %%
artist_df['album']
# Out:
# 0    [Her Loss, Her Loss, Honestly, Nevermind, Hone...
# 1    [One Thing At A Time, One Thing At A Time, Dan...
# 2    [It's Only Me, It's Only Me, The Voice of the ...
# 3    [Midnights (The Til Dawn Edition), Midnights (...
# 4    [Twelve Carat Toothache (Deluxe), Twelve Carat...
# 5    [Gettin' Old, Growin' Up, What You See Ain't A...
# 6    [Planet Her (Deluxe), Planet Her (Deluxe), Pla...
# 7    [Baby On Baby 2, Baby On Baby 2, BETTER THAN Y...
# 8    [SOS, SOS, Ctrl (Deluxe), Dear Evan Hansen (Or...
# 9    [Happier Than Ever, Happier Than Ever, WHEN WE...
# Name: album, dtype: object

# %%
r.keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %%
artist_df['album'].keys()
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
data = []
albums = []

# %%
def album_features(artist_id):
    r = requests.get(BASE_URL + 'artists/' + artist_id + '/albums', 
                 headers=headers, 
                 params={'include_groups': 'album', 'limit': 50})
    d = r.json()
    
    for album in d['items']:
        album_name = album['name']
    
    # here's a hacky way to skip over albums we've already grabbed
    trim_name = album_name.split('(')[0].strip()

    
    # this takes a few seconds so let's keep track of progress    
    
    
    # pull all tracks from this album
    a_tracks = requests.get(BASE_URL + 'albums/' + album['id'] + '/tracks', 
        headers=headers)
    tracks = a_tracks.json()['items']
    
    for track in tracks:
        # get audio features (key, liveness, danceability, ...)
        f = requests.get(BASE_URL + 'audio-features/' + track['id'], 
            headers=headers)
        f = f.json()
        
        # combine with album info
        f.update({
            'track_name': track['name'],
            'album_name': album_name,
            'short_album_name': trim_name,
            'release_date': album['release_date'],
            'album_id': album['id'], 'artist_id': artist_id
        })
        
        data.append(f)

    return data

# %%
album_features('5pKCCKE2ajJHZ9KAiaK11H')
# Out:
# [{'danceability': 0.779,
#   'energy': 0.64,
#   'key': 7,
#   'loudness': -8.415,
#   'mode': 1,
#   'speechiness': 0.159,
#   'acousticness': 0.000155,
#   'instrumentalness': 0.00077,
#   'liveness': 0.101,
#   'valence': 0.498,
#   'tempo': 99.019,
#   'type': 'audio_features',
#   'id': '4TsmezEQVSZNNPv5RJ65Ov',
#   'uri': 'spotify:track:4TsmezEQVSZNNPv5RJ65Ov',
#   'track_href': 'https://api.spotify.com/v1/tracks/4TsmezEQVSZNNPv5RJ65Ov',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4TsmezEQVSZNNPv5RJ65Ov',
#   'duration_ms': 246960,
#   'time_signature': 4,
#   'track_name': 'Pon de Replay',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.681,
#   'energy': 0.611,
#   'key': 5,
#   'loudness': -5.939,
#   'mode': 0,
#   'speechiness': 0.077,
#   'acousticness': 0.000332,
#   'instrumentalness': 0.00193,
#   'liveness': 0.12,
#   'valence': 0.637,
#   'tempo': 83.463,
#   'type': 'audio_features',
#   'id': '07gLSfLyr23jSKaUpRgR1B',
#   'uri': 'spotify:track:07gLSfLyr23jSKaUpRgR1B',
#   'track_href': 'https://api.spotify.com/v1/tracks/07gLSfLyr23jSKaUpRgR1B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/07gLSfLyr23jSKaUpRgR1B',
#   'duration_ms': 251133,
#   'time_signature': 4,
#   'track_name': 'Here I Go Again',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.745,
#   'energy': 0.694,
#   'key': 8,
#   'loudness': -7.519,
#   'mode': 1,
#   'speechiness': 0.128,
#   'acousticness': 0.0962,
#   'instrumentalness': 0,
#   'liveness': 0.0454,
#   'valence': 0.74,
#   'tempo': 95.924,
#   'type': 'audio_features',
#   'id': '4x2rgtSFOI4hRvEvDj02KP',
#   'uri': 'spotify:track:4x2rgtSFOI4hRvEvDj02KP',
#   'track_href': 'https://api.spotify.com/v1/tracks/4x2rgtSFOI4hRvEvDj02KP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4x2rgtSFOI4hRvEvDj02KP',
#   'duration_ms': 208107,
#   'time_signature': 4,
#   'track_name': "If It's Lovin' That You Want",
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.691,
#   'energy': 0.667,
#   'key': 2,
#   'loudness': -6.496,
#   'mode': 1,
#   'speechiness': 0.0769,
#   'acousticness': 0.00632,
#   'instrumentalness': 4.46e-06,
#   'liveness': 0.0816,
#   'valence': 0.611,
#   'tempo': 84.008,
#   'type': 'audio_features',
#   'id': '7wWU3G8lAYNkro19o1wsBc',
#   'uri': 'spotify:track:7wWU3G8lAYNkro19o1wsBc',
#   'track_href': 'https://api.spotify.com/v1/tracks/7wWU3G8lAYNkro19o1wsBc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7wWU3G8lAYNkro19o1wsBc',
#   'duration_ms': 260067,
#   'time_signature': 4,
#   'track_name': "You Don't Love Me (No, No, No)",
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.853,
#   'energy': 0.672,
#   'key': 7,
#   'loudness': -5.996,
#   'mode': 0,
#   'speechiness': 0.391,
#   'acousticness': 0.222,
#   'instrumentalness': 1.41e-06,
#   'liveness': 0.297,
#   'valence': 0.952,
#   'tempo': 77.501,
#   'type': 'audio_features',
#   'id': '2JMgGr5NopZc83ECon8MBj',
#   'uri': 'spotify:track:2JMgGr5NopZc83ECon8MBj',
#   'track_href': 'https://api.spotify.com/v1/tracks/2JMgGr5NopZc83ECon8MBj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2JMgGr5NopZc83ECon8MBj',
#   'duration_ms': 225867,
#   'time_signature': 4,
#   'track_name': 'That La, La, La',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.65,
#   'energy': 0.494,
#   'key': 9,
#   'loudness': -7.021,
#   'mode': 0,
#   'speechiness': 0.0538,
#   'acousticness': 0.0232,
#   'instrumentalness': 0,
#   'liveness': 0.104,
#   'valence': 0.114,
#   'tempo': 111.68,
#   'type': 'audio_features',
#   'id': '2IRrmMVmjvWQjJGY8LNuk5',
#   'uri': 'spotify:track:2IRrmMVmjvWQjJGY8LNuk5',
#   'track_href': 'https://api.spotify.com/v1/tracks/2IRrmMVmjvWQjJGY8LNuk5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2IRrmMVmjvWQjJGY8LNuk5',
#   'duration_ms': 293227,
#   'time_signature': 4,
#   'track_name': 'The Last Time',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.537,
#   'energy': 0.443,
#   'key': 10,
#   'loudness': -8.407,
#   'mode': 0,
#   'speechiness': 0.107,
#   'acousticness': 0.0107,
#   'instrumentalness': 6.99e-05,
#   'liveness': 0.166,
#   'valence': 0.281,
#   'tempo': 84.597,
#   'type': 'audio_features',
#   'id': '5b41vHKBfpyEbmkJu6wtlH',
#   'uri': 'spotify:track:5b41vHKBfpyEbmkJu6wtlH',
#   'track_href': 'https://api.spotify.com/v1/tracks/5b41vHKBfpyEbmkJu6wtlH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5b41vHKBfpyEbmkJu6wtlH',
#   'duration_ms': 277973,
#   'time_signature': 4,
#   'track_name': 'Willing To Wait',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.535,
#   'energy': 0.643,
#   'key': 0,
#   'loudness': -8.182,
#   'mode': 1,
#   'speechiness': 0.155,
#   'acousticness': 0.112,
#   'instrumentalness': 0,
#   'liveness': 0.281,
#   'valence': 0.632,
#   'tempo': 171.884,
#   'type': 'audio_features',
#   'id': '3vPkkIsaQ5NqOqvj7Ht8kR',
#   'uri': 'spotify:track:3vPkkIsaQ5NqOqvj7Ht8kR',
#   'track_href': 'https://api.spotify.com/v1/tracks/3vPkkIsaQ5NqOqvj7Ht8kR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3vPkkIsaQ5NqOqvj7Ht8kR',
#   'duration_ms': 236027,
#   'time_signature': 4,
#   'track_name': 'Music Of The Sun',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.753,
#   'energy': 0.771,
#   'key': 5,
#   'loudness': -5.833,
#   'mode': 0,
#   'speechiness': 0.145,
#   'acousticness': 0.0541,
#   'instrumentalness': 0.000304,
#   'liveness': 0.133,
#   'valence': 0.743,
#   'tempo': 108.022,
#   'type': 'audio_features',
#   'id': '4tAqWkqjX9bRSUpNcYviVf',
#   'uri': 'spotify:track:4tAqWkqjX9bRSUpNcYviVf',
#   'track_href': 'https://api.spotify.com/v1/tracks/4tAqWkqjX9bRSUpNcYviVf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4tAqWkqjX9bRSUpNcYviVf',
#   'duration_ms': 236400,
#   'time_signature': 4,
#   'track_name': 'Let Me',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.751,
#   'energy': 0.822,
#   'key': 1,
#   'loudness': -4.533,
#   'mode': 1,
#   'speechiness': 0.164,
#   'acousticness': 0.001,
#   'instrumentalness': 0.0022,
#   'liveness': 0.259,
#   'valence': 0.801,
#   'tempo': 96.967,
#   'type': 'audio_features',
#   'id': '5NH2an2qR7M6ptHnxTfhP1',
#   'uri': 'spotify:track:5NH2an2qR7M6ptHnxTfhP1',
#   'track_href': 'https://api.spotify.com/v1/tracks/5NH2an2qR7M6ptHnxTfhP1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NH2an2qR7M6ptHnxTfhP1',
#   'duration_ms': 189573,
#   'time_signature': 4,
#   'track_name': 'Rush',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.572,
#   'energy': 0.632,
#   'key': 0,
#   'loudness': -7.742,
#   'mode': 1,
#   'speechiness': 0.109,
#   'acousticness': 0.00138,
#   'instrumentalness': 3.85e-06,
#   'liveness': 0.102,
#   'valence': 0.572,
#   'tempo': 161.786,
#   'type': 'audio_features',
#   'id': '2O5rxPXXEFuvVfvsc85GX3',
#   'uri': 'spotify:track:2O5rxPXXEFuvVfvsc85GX3',
#   'track_href': 'https://api.spotify.com/v1/tracks/2O5rxPXXEFuvVfvsc85GX3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2O5rxPXXEFuvVfvsc85GX3',
#   'duration_ms': 198640,
#   'time_signature': 4,
#   'track_name': "There's A Thug In My Life",
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.315,
#   'energy': 0.267,
#   'key': 9,
#   'loudness': -11.355,
#   'mode': 1,
#   'speechiness': 0.0289,
#   'acousticness': 0.853,
#   'instrumentalness': 1.5e-06,
#   'liveness': 0.204,
#   'valence': 0.22,
#   'tempo': 104.987,
#   'type': 'audio_features',
#   'id': '35Hibmn6fwoYVifZ9TKnWg',
#   'uri': 'spotify:track:35Hibmn6fwoYVifZ9TKnWg',
#   'track_href': 'https://api.spotify.com/v1/tracks/35Hibmn6fwoYVifZ9TKnWg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35Hibmn6fwoYVifZ9TKnWg',
#   'duration_ms': 300587,
#   'time_signature': 3,
#   'track_name': 'Now I Know',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'},
#  {'danceability': 0.778,
#   'energy': 0.737,
#   'key': 7,
#   'loudness': -7.861,
#   'mode': 1,
#   'speechiness': 0.251,
#   'acousticness': 0.00031,
#   'instrumentalness': 0,
#   'liveness': 0.276,
#   'valence': 0.582,
#   'tempo': 99.078,
#   'type': 'audio_features',
#   'id': '1B4iEymNy6FyU2I39ujzVw',
#   'uri': 'spotify:track:1B4iEymNy6FyU2I39ujzVw',
#   'track_href': 'https://api.spotify.com/v1/tracks/1B4iEymNy6FyU2I39ujzVw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1B4iEymNy6FyU2I39ujzVw',
#   'duration_ms': 217187,
#   'time_signature': 4,
#   'track_name': 'Pon De Replay - Remix',
#   'album_name': 'Music Of The Sun',
#   'short_album_name': 'Music Of The Sun',
#   'release_date': '2005-08-29',
#   'album_id': '4FyGpObwABjn0o8Tdp7AZz',
#   'artist_id': '5pKCCKE2ajJHZ9KAiaK11H'}]

# %%
artist_df["Features"] = artist_df['id'].apply(album_features)

# %%
artist_df
# Out:
#             name                      id  \
# 0          Drake  3TVXtAsR1Inumwj472S9r4
# 1  Morgan Wallen  4oUHIQIBe0LHzYfvXNW4QM
# 2       Lil Baby  5f7VJjfbwm532GiveGC0ZK
# 3   Taylor Swift  06HL4z0CvFAxyc27GXpf02
# 4    Post Malone  246dkjvS1zLTtiykXe5h60
# 5     Luke Combs  718COspgdWOnwOFpJHRZHS
# 6       Doja Cat  5cj0lLjcoR7YOSnhnX0Po5
# 7         DaBaby  4r63FhuTkUYltbVAg5TQnk
# 8            SZA  7tYKF4w9nC0nq9CsPZTHyP
# 9  Billie Eilish  6qqNVTkY8uBg9cP3Jd7DAH
#
#                                                album  \
# 0  [Her Loss, Her Loss, Honestly, Nevermind, Hone...
# 1  [One Thing At A Time, One Thing At A Time, Dan...
# 2  [It's Only Me, It's Only Me, The Voice of the ...
# 3  [Midnights (The Til Dawn Edition), Midnights (...
# 4  [Twelve Carat Toothache (Deluxe), Twelve Carat...
# 5  [Gettin' Old, Growin' Up, What You See Ain't A...
# 6  [Planet Her (Deluxe), Planet Her (Deluxe), Pla...
# 7  [Baby On Baby 2, Baby On Baby 2, BETTER THAN Y...
# 8  [SOS, SOS, Ctrl (Deluxe), Dear Evan Hansen (Or...
# 9  [Happier Than Ever, Happier Than Ever, WHEN WE...
#
#                                             Features
# 0  [{'danceability': 0.779, 'energy': 0.64, 'key'...
# 1  [{'danceability': 0.779, 'energy': 0.64, 'key'...
# 2  [{'danceability': 0.779, 'energy': 0.64, 'key'...
# 3  [{'danceability': 0.779, 'energy': 0.64, 'key'...
# 4  [{'danceability': 0.779, 'energy': 0.64, 'key'...
# 5  [{'danceability': 0.779, 'energy': 0.64, 'key'...
# 6  [{'danceability': 0.779, 'energy': 0.64, 'key'...
# 7  [{'danceability': 0.779, 'energy': 0.64, 'key'...
# 8  [{'danceability': 0.779, 'energy': 0.64, 'key'...
# 9  [{'danceability': 0.779, 'energy': 0.64, 'key'...

# %%
artist_df.to_csv('artist_info.csv')

# %%
df = pd.DataFrame(data)

# %%
df.keys()
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'track_name', 'album_name', 'short_album_name',
#        'release_date', 'album_id', 'artist_id'],
#       dtype='object')

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df = df.sort_values(by='release_date')

# %%
df["artist"] = df['artist_id'].apply(album_features)

# %%
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.779   0.640    7    -8.415     1       0.1590      0.000155
# 12          0.778   0.737    7    -7.861     1       0.2510      0.000310
# 11          0.315   0.267    9   -11.355     1       0.0289      0.853000
# 9           0.751   0.822    1    -4.533     1       0.1640      0.001000
# 8           0.753   0.771    5    -5.833     0       0.1450      0.054100
# ..            ...     ...  ...       ...   ...          ...           ...
# 132         0.701   0.425    7   -10.965     1       0.3750      0.328000
# 131         0.000   0.278    1   -21.630     1       0.0000      0.768000
# 143         0.421   0.131    0   -18.435     1       0.0382      0.952000
# 136         0.853   0.351    7   -10.198     1       0.2410      0.390000
# 144         0.153   0.138    6   -21.877     0       0.0503      0.837000
#
#      instrumentalness  liveness  valence  ...  \
# 0            0.000770     0.101   0.4980  ...
# 12           0.000000     0.276   0.5820  ...
# 11           0.000002     0.204   0.2200  ...
# 9            0.002200     0.259   0.8010  ...
# 8            0.000304     0.133   0.7430  ...
# ..                ...       ...      ...  ...
# 132          0.130000     0.100   0.5620  ...
# 131          0.000000     0.669   0.0000  ...
# 143          0.004530     0.109   0.1200  ...
# 136          0.000009     0.752   0.2820  ...
# 144          0.550000     0.254   0.0503  ...
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/4TsmezEQVSZN...
# 12   https://api.spotify.com/v1/tracks/1B4iEymNy6Fy...
# 11   https://api.spotify.com/v1/tracks/35Hibmn6fwoY...
# 9    https://api.spotify.com/v1/tracks/5NH2an2qR7M6...
# 8    https://api.spotify.com/v1/tracks/4tAqWkqjX9bR...
# ..                                                 ...
# 132  https://api.spotify.com/v1/tracks/2Fxmhks0bxGS...
# 131  https://api.spotify.com/v1/tracks/0rQtoQXQfwpD...
# 143  https://api.spotify.com/v1/tracks/6CcJMwBtXByI...
# 136  https://api.spotify.com/v1/tracks/3Fj47GNK2kUF...
# 144  https://api.spotify.com/v1/tracks/3LgWsmilsrWX...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/4Tsm...      246960
# 12   https://api.spotify.com/v1/audio-analysis/1B4i...      217187
# 11   https://api.spotify.com/v1/audio-analysis/35Hi...      300587
# 9    https://api.spotify.com/v1/audio-analysis/5NH2...      189573
# 8    https://api.spotify.com/v1/audio-analysis/4tAq...      236400
# ..                                                 ...         ...
# 132  https://api.spotify.com/v1/audio-analysis/2Fxm...      194088
# 131  https://api.spotify.com/v1/audio-analysis/0rQt...       13578
# 143  https://api.spotify.com/v1/audio-analysis/6CcJ...      291796
# 136  https://api.spotify.com/v1/audio-analysis/3Fj4...      221543
# 144  https://api.spotify.com/v1/audio-analysis/3LgW...      119410
#
#     time_signature             track_name  \
# 0                4          Pon de Replay
# 12               4  Pon De Replay - Remix
# 11               3             Now I Know
# 9                4                   Rush
# 8                4                 Let Me
# ..             ...                    ...
# 132              4                bad guy
# 131              0                !!!!!!!
# 143              4             i love you
# 136              4      wish you were gay
# 144              3                goodbye
#
#                                    album_name  \
# 0                            Music Of The Sun
# 12                           Music Of The Sun
# 11                           Music Of The Sun
# 9                            Music Of The Sun
# 8                            Music Of The Sun
# ..                                        ...
# 132  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 131  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 143  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 136  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 144  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
#
#                              short_album_name  release_date  \
# 0                            Music Of The Sun    2005-08-29
# 12                           Music Of The Sun    2005-08-29
# 11                           Music Of The Sun    2005-08-29
# 9                            Music Of The Sun    2005-08-29
# 8                            Music Of The Sun    2005-08-29
# ..                                        ...           ...
# 132  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?    2019-03-29
# 131  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?    2019-03-29
# 143  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?    2019-03-29
# 136  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?    2019-03-29
# 144  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?    2019-03-29
#
#                    album_id               artist_id
# 0    4FyGpObwABjn0o8Tdp7AZz  5pKCCKE2ajJHZ9KAiaK11H
# 12   4FyGpObwABjn0o8Tdp7AZz  5pKCCKE2ajJHZ9KAiaK11H
# 11   4FyGpObwABjn0o8Tdp7AZz  5pKCCKE2ajJHZ9KAiaK11H
# 9    4FyGpObwABjn0o8Tdp7AZz  5pKCCKE2ajJHZ9KAiaK11H
# 8    4FyGpObwABjn0o8Tdp7AZz  5pKCCKE2ajJHZ9KAiaK11H
# ..                      ...                     ...
# 132  0S0KGZnfBGSIssfF54WSJh  6qqNVTkY8uBg9cP3Jd7DAH
# 131  0S0KGZnfBGSIssfF54WSJh  6qqNVTkY8uBg9cP3Jd7DAH
# 143  0S0KGZnfBGSIssfF54WSJh  6qqNVTkY8uBg9cP3Jd7DAH
# 136  0S0KGZnfBGSIssfF54WSJh  6qqNVTkY8uBg9cP3Jd7DAH
# 144  0S0KGZnfBGSIssfF54WSJh  6qqNVTkY8uBg9cP3Jd7DAH
#
# [145 rows x 24 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))

ax = sns.scatterplot(data= df, x='danceability', y='acousticness', 
                     hue='short_album_name', palette='rainbow', 
                     size='duration_ms', sizes=(50,1000), 
                     alpha=0.7)

# display legend without `size` attribute
h,labs = ax.get_legend_handles_labels()
ax.legend(h[1:10], labs[1:10], loc='best', title=None)

# %%
plt.figure(figsize=(10,10))

ax = sns.scatterplot(data= df , x='danceability', y='acousticness', 
                     hue='short_album_name', palette='rainbow', 
                     size='duration_ms', sizes=(50,1000), 
                     alpha=0.7)

# display legend without `size` attribute
h,labs = ax.get_legend_handles_labels()
ax.legend(h[1:10], labs[1:10], loc='best', title=None)

# %%
import plotnine

# %%
from plotnine import ggplot, geom_point, aes, stat_smooth, facet_wrap

# %%
(ggplot(df, aes('release_date','danceability',  color='short_album_name'))
 + geom_point()
 )
# Out:
# <ggplot: (8776642329766)>

# %%
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 648         0.778   0.737    7    -7.861     1       0.2510      0.000310
# 622         0.756   0.632    7    -8.441     1       0.1640      0.000165
# 623         0.677   0.614    8    -5.935     1       0.0732      0.000364
# 624         0.572   0.693    8    -7.492     1       0.2690      0.100000
# 625         0.692   0.678    2    -6.517     1       0.0840      0.006530
# ..            ...     ...  ...       ...   ...          ...           ...
# 17          0.513   0.692    9    -6.030     1       0.0398      0.366000
# 18          0.570   0.510    5   -13.850     1       0.7650      0.718000
# 19          0.465   0.260    0    -8.179     0       0.0310      0.475000
# 10          0.787   0.598    1    -7.457     1       0.2120      0.573000
# 0           0.247   0.299    9    -6.083     1       0.0315      0.899000
#
#      instrumentalness  liveness  valence  ...  \
# 648          0.000000    0.2760    0.582  ...
# 622          0.000886    0.0963    0.505  ...
# 623          0.001580    0.1070    0.643  ...
# 624          0.000000    0.0426    0.757  ...
# 625          0.000002    0.1390    0.610  ...
# ..                ...       ...      ...  ...
# 17           0.000000    0.1510    0.534  ...
# 18           0.000467    0.0979    0.138  ...
# 19           0.000000    0.1380    0.259  ...
# 10           0.000002    0.1030    0.820  ...
# 0            0.000000    0.1310    0.172  ...
#
#                                       uri  \
# 648  spotify:track:1B4iEymNy6FyU2I39ujzVw
# 622  spotify:track:3U3Ff8ZvL6oEu1r98gCCWW
# 623  spotify:track:6N2E4G9gU2yxJYJndMPsYE
# 624  spotify:track:1Q29dre9FCspRSarHziizl
# 625  spotify:track:1vSCj9zmP1zRD1D5ruLUkR
# ..                                    ...
# 17   spotify:track:1p9R4HF2WGtZDISBxMwF3R
# 18   spotify:track:3c1YCQvr720s61gHPgtkv8
# 19   spotify:track:18zQTt3ifDv6iLni2YuXMg
# 10   spotify:track:02dF3qjpgTpmPCBKo72C06
# 0    spotify:track:6sCvvleqKbeyOkQDieBYgp
#
#                                             track_href  \
# 648  https://api.spotify.com/v1/tracks/1B4iEymNy6Fy...
# 622  https://api.spotify.com/v1/tracks/3U3Ff8ZvL6oE...
# 623  https://api.spotify.com/v1/tracks/6N2E4G9gU2yx...
# 624  https://api.spotify.com/v1/tracks/1Q29dre9FCsp...
# 625  https://api.spotify.com/v1/tracks/1vSCj9zmP1zR...
# ..                                                 ...
# 17   https://api.spotify.com/v1/tracks/1p9R4HF2WGtZ...
# 18   https://api.spotify.com/v1/tracks/3c1YCQvr720s...
# 19   https://api.spotify.com/v1/tracks/18zQTt3ifDv6...
# 10   https://api.spotify.com/v1/tracks/02dF3qjpgTpm...
# 0    https://api.spotify.com/v1/tracks/6sCvvleqKbey...
#
#                                           analysis_url duration_ms  \
# 648  https://api.spotify.com/v1/audio-analysis/1B4i...      217187
# 622  https://api.spotify.com/v1/audio-analysis/3U3F...      246960
# 623  https://api.spotify.com/v1/audio-analysis/6N2E...      251133
# 624  https://api.spotify.com/v1/audio-analysis/1Q29...      208107
# 625  https://api.spotify.com/v1/audio-analysis/1vSC...      260067
# ..                                                 ...         ...
# 17   https://api.spotify.com/v1/audio-analysis/1p9R...      222000
# 18   https://api.spotify.com/v1/audio-analysis/3c1Y...      160480
# 19   https://api.spotify.com/v1/audio-analysis/18zQ...      213333
# 10   https://api.spotify.com/v1/audio-analysis/02dF...      224747
# 0    https://api.spotify.com/v1/audio-analysis/6sCv...      196520
#
#     time_signature                                         track_name  \
# 648              4                              Pon De Replay - Remix
# 622              4                                      Pon de Replay
# 623              4                                    Here I Go Again
# 624              4                       If It's Lovin' That You Want
# 625              4                     You Don't Love Me (No, No, No)
# ..             ...                                                ...
# 17               1                                 No Digas Mi Nombre
# 18               3                                          Mi Pueblo
# 19               4                                         Born Again
# 10               4                               Laayli' kuxa'ano'one
# 0                4  Lift Me Up - From Black Panther: Wakanda Forev...
#
#                                             album_name  \
# 648                                   Music Of The Sun
# 622                                   Music Of The Sun
# 623                                   Music Of The Sun
# 624                                   Music Of The Sun
# 625                                   Music Of The Sun
# ..                                                 ...
# 17   Black Panther: Wakanda Forever - Music From an...
# 18   Black Panther: Wakanda Forever - Music From an...
# 19   Black Panther: Wakanda Forever - Music From an...
# 10   Black Panther: Wakanda Forever - Music From an...
# 0    Black Panther: Wakanda Forever - Music From an...
#
#                                       short_album_name release_date  \
# 648                                   Music Of The Sun   2005-08-29
# 622                                   Music Of The Sun   2005-08-29
# 623                                   Music Of The Sun   2005-08-29
# 624                                   Music Of The Sun   2005-08-29
# 625                                   Music Of The Sun   2005-08-29
# ..                                                 ...          ...
# 17   Black Panther: Wakanda Forever - Music From an...   2022-11-11
# 18   Black Panther: Wakanda Forever - Music From an...   2022-11-11
# 19   Black Panther: Wakanda Forever - Music From an...   2022-11-11
# 10   Black Panther: Wakanda Forever - Music From an...   2022-11-11
# 0    Black Panther: Wakanda Forever - Music From an...   2022-11-11
#
#                    album_id
# 648  4FyGpObwABjn0o8Tdp7AZz
# 622  19UbDbyaYRW1U7lBMYO9F2
# 623  19UbDbyaYRW1U7lBMYO9F2
# 624  19UbDbyaYRW1U7lBMYO9F2
# 625  19UbDbyaYRW1U7lBMYO9F2
# ..                      ...
# 17   06RK0wX4GqHcxBtHlVoGH5
# 18   06RK0wX4GqHcxBtHlVoGH5
# 19   06RK0wX4GqHcxBtHlVoGH5
# 10   06RK0wX4GqHcxBtHlVoGH5
# 0    06RK0wX4GqHcxBtHlVoGH5
#
# [645 rows x 23 columns]

# %%
API_KEY = 'XXX'
USER_AGENT = 'Dataquest'

# %%
import requests

headers = {
    'user-agent': USER_AGENT
}

payload = {
    'api_key': API_KEY,
    'method': 'chart.gettopartists',
    'format': 'json'
}

r = requests.get('https://ws.audioscrobbler.com/2.0/', headers=headers, params=payload)
r.status_code
# Out:
# 200

# %%
def lastfm_get(payload):
    # define headers and URL
    headers = {'user-agent': USER_AGENT}
    url = 'https://ws.audioscrobbler.com/2.0/'

    # Add API key and format to the payload
    payload['api_key'] = API_KEY
    payload['format'] = 'json'

    response = requests.get(url, headers=headers, params=payload)
    return response

# %%
r = lastfm_get({
    'method': 'chart.gettopartists'
})

r.status_code
# Out:
# 200

# %%
import json

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

jprint(r.json())
# Out:
# {
#     "artists": {
#         "@attr": {
#             "page": "1",
#             "perPage": "50",
#             "total": "4614402",
#             "totalPages": "92289"
#         },
#         "artist": [
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "3159614",
#                 "mbid": "c8b03190-306c-4120-bb0b-6f2ebfc06ea9",
#                 "name": "The Weeknd",
#                 "playcount": "437423368",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/The+Weeknd"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "3849887",
#                 "mbid": "20244d07-534f-4eff-b4d4-930878889970",
#                 "name": "Taylor Swift",
#                 "playcount": "1219100721",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Taylor+Swift"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1763377",
#                 "mbid": "272989c8-5535-492d-a25c-9f58803e027f",
#                 "name": "SZA",
#                 "playcount": "181433997",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/SZA"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2910733",
#                 "mbid": "381086ea-f511-4aba-bdf9-71c753dc5077",
#                 "name": "Kendrick Lamar",
#                 "playcount": "358832525",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Kendrick+Lamar"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "5910734",
#                 "mbid": "164f0d73-1234-4e2c-8743-d77bf2191051",
#                 "name": "Kanye West",
#                 "playcount": "737194078",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Kanye+West"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "3282015",
#                 "mbid": "b7539c32-53e7-4908-bda3-81449c367da6",
#                 "name": "Lana Del Rey",
#                 "playcount": "589647836",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Lana+Del+Rey"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "4856202",
#                 "mbid": "b49b81cc-d5b7-4bdd-aadb-385df8de69a6",
#                 "name": "Drake",
#                 "playcount": "438841117",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Drake"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "6039817",
#                 "mbid": "db36a76f-4cdf-43ac-8cd0-5e48092d2bae",
#                 "name": "Rihanna",
#                 "playcount": "311669353",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Rihanna"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "4862199",
#                 "mbid": "e21857d5-3256-4547-afb3-4b6ded592596",
#                 "name": "Gorillaz",
#                 "playcount": "284095366",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Gorillaz"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "4935940",
#                 "mbid": "ada7a83c-e3e1-40f1-93f9-3e73dbc9298a",
#                 "name": "Arctic Monkeys",
#                 "playcount": "520718795",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Arctic+Monkeys"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2176703",
#                 "mbid": "f6beac20-5dfe-4d1f-ae02-0b0a740aafd6",
#                 "name": "Tyler, the Creator",
#                 "playcount": "339358380",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Tyler,+the+Creator"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1074097",
#                 "mbid": "",
#                 "name": "pinkpantheress",
#                 "playcount": "48973113",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/pinkpantheress"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2529475",
#                 "mbid": "e520459c-dff4-491d-a6e4-c97be35e0044",
#                 "name": "Frank Ocean",
#                 "playcount": "323359240",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Frank+Ocean"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2126258",
#                 "mbid": "",
#                 "name": "Billie Eilish",
#                 "playcount": "249535161",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Billie+Eilish"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "3307430",
#                 "mbid": "7e9bd05a-117f-4cce-87bc-e011527a8b18",
#                 "name": "Miley Cyrus",
#                 "playcount": "171054570",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Miley+Cyrus"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2424156",
#                 "mbid": "63aa26c3-d59b-4da4-84ac-716b54f1ef4d",
#                 "name": "Tame Impala",
#                 "playcount": "185010231",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Tame+Impala"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1851651",
#                 "mbid": "5df62a88-cac9-490a-b62c-c7c88f4020f4",
#                 "name": "Doja Cat",
#                 "playcount": "190039193",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Doja+Cat"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1860212",
#                 "mbid": "",
#                 "name": "Harry Styles",
#                 "playcount": "218875820",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Harry+Styles"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "5891388",
#                 "mbid": "a74b1b7f-71a5-4011-9441-d0b5e4122711",
#                 "name": "Radiohead",
#                 "playcount": "699462007",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Radiohead"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2580677",
#                 "mbid": "f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387",
#                 "name": "Ariana Grande",
#                 "playcount": "413073652",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Ariana+Grande"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "5213310",
#                 "mbid": "650e7db6-b795-4eb5-a702-5ea2fc46c848",
#                 "name": "Lady Gaga",
#                 "playcount": "482650492",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Lady+Gaga"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "6802971",
#                 "mbid": "cc197bad-dc9c-440d-a5b5-d52ba2e14234",
#                 "name": "Coldplay",
#                 "playcount": "511654059",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Coldplay"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "4813386",
#                 "mbid": "859d0860-d480-4efd-970c-c05d5f1776b8",
#                 "name": "Beyonc\u00e9",
#                 "playcount": "313331853",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Beyonc%C3%A9"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1399885",
#                 "mbid": "ca9766a0-1c30-43e6-a213-bac1334efc4a",
#                 "name": "Steve Lacy",
#                 "playcount": "93753806",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Steve+Lacy"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1393696",
#                 "mbid": "",
#                 "name": "Kali Uchis",
#                 "playcount": "95612173",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Kali+Uchis"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2166681",
#                 "mbid": "7fb57fba-a6ef-44c2-abab-2fa3bdee607e",
#                 "name": "Childish Gambino",
#                 "playcount": "141814969",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Childish+Gambino"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2164200",
#                 "mbid": "97b8d224-5660-419c-8dff-4b3bf0c33983",
#                 "name": "The Neighbourhood",
#                 "playcount": "152092495",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/The+Neighbourhood"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "3622052",
#                 "mbid": "728ea90d-279b-4201-a8c4-597830883150",
#                 "name": "Paramore",
#                 "playcount": "285603371",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Paramore"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "5881127",
#                 "mbid": "b95ce3ff-3d05-4e87-9e01-c97b66af13d4",
#                 "name": "Eminem",
#                 "playcount": "326928469",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Eminem"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "996364",
#                 "mbid": "",
#                 "name": "Metro Boomin",
#                 "playcount": "58584562",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Metro+Boomin"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1995334",
#                 "mbid": "",
#                 "name": "Post Malone",
#                 "playcount": "152410596",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Post+Malone"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1603940",
#                 "mbid": "",
#                 "name": "Joji",
#                 "playcount": "161570021",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Joji"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "3259910",
#                 "mbid": "afb680f2-b6eb-4cd7-a70b-a63b25c763d5",
#                 "name": "Bruno Mars",
#                 "playcount": "128444218",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Bruno+Mars"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "5481083",
#                 "mbid": "9282c8b4-ca0b-4c6b-b7e3-4f7762dfc4d6",
#                 "name": "Nirvana",
#                 "playcount": "322021475",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Nirvana"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1602339",
#                 "mbid": "f2492c31-54a8-4347-a1fc-f81f72873bbf",
#                 "name": "Mac DeMarco",
#                 "playcount": "119347996",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Mac+DeMarco"
#             },
#             {
#                 "image": [
#                     {
# ...
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2162599",
#                 "mbid": "a0e8a1b1-5f8f-475a-a253-17415c17d0ff",
#                 "name": "Mac Miller",
#                 "playcount": "197110320",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Mac+Miller"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1316829",
#                 "mbid": "fa58cf24-0e44-421d-8519-8bf461dcfaa5",
#                 "name": "Mitski",
#                 "playcount": "198554813",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Mitski"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1313730",
#                 "mbid": "e4a51f17-a57b-47b1-b37b-f552d0f8e9e6",
#                 "name": "Travis Scott",
#                 "playcount": "131714996",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Travis+Scott"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "4783963",
#                 "mbid": "b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d",
#                 "name": "The Beatles",
#                 "playcount": "682511190",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/The+Beatles"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2378561",
#                 "mbid": "8e494408-8620-4c6a-82c2-c2ca4a1e4f12",
#                 "name": "Lorde",
#                 "playcount": "207358097",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Lorde"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "3228136",
#                 "mbid": "40f5d9e4-2de7-4f2d-ad41-e31a9a9fea27",
#                 "name": "The Smiths",
#                 "playcount": "252452729",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/The+Smiths"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "3394134",
#                 "mbid": "8dd98bdc-80ec-4e93-8509-2f46bafc09a7",
#                 "name": "Calvin Harris",
#                 "playcount": "118489793",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Calvin+Harris"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1129505",
#                 "mbid": "",
#                 "name": "Playboi Carti",
#                 "playcount": "248486355",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Playboi+Carti"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "4322356",
#                 "mbid": "f82bcf78-5b69-4622-a5ef-73800768d9ac",
#                 "name": "Jay-Z",
#                 "playcount": "144007855",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Jay-Z"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "2619694",
#                 "mbid": "875203e1-8e58-4b86-8dcb-7190faf411c5",
#                 "name": "J. Cole",
#                 "playcount": "136562241",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/J.+Cole"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "3195343",
#                 "mbid": "1036b808-f58c-4a3e-b461-a2c4492ecf1b",
#                 "name": "Nicki Minaj",
#                 "playcount": "152148605",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/Nicki+Minaj"
#             },
#             {
#                 "image": [
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "small"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "medium"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "large"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "extralarge"
#                     },
#                     {
#                         "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#                         "size": "mega"
#                     }
#                 ],
#                 "listeners": "1473495",
#                 "mbid": "",
#                 "name": "xxxtentacion",
#                 "playcount": "145037119",
#                 "streamable": "0",
#                 "url": "https://www.last.fm/music/xxxtentacion"
#             }
#         ]
#     }
# }

# %%
jprint(r.json()['artists']['@attr'])
# Out:
# {
#     "page": "1",
#     "perPage": "50",
#     "total": "4614402",
#     "totalPages": "92289"
# }

# %%
from requests_cache import CachedSession, RedisCache, json_serializer

# %%
import requests_cache

requests_cache.install_cache()

# %%
import time
from IPython.core.display import clear_output

responses = []

page = 1
total_pages = 99999 

while page <= total_pages:
    payload = {
        'method': 'chart.gettopartists',
        'limit': 500,
        'page': page
    }

    # print some output so we can see the status
    print("Requesting page {}/{}".format(page, total_pages))
    # clear the output to make things neater
    clear_output(wait = True)

    # make the API call
    response = lastfm_get(payload)

    # if we get an error, print the response and halt the loop
    if response.status_code != 200:
        print(response.text)
        break

    # extract page info
    page = int(response.json()['artists']['@attr']['page'])
    total_pages = int(response.json()['artists']['@attr']['totalPages'])

    # append response
    responses.append(response)

    # if it's not a cached result, sleep
    if not getattr(response, 'from_cache', False):
        time.sleep(0.25)

    # increment the page number
    page += 1
# Out:
# Requesting page 9188/9188

# %%
r0 = responses[0]
r0_json = r0.json()
r0_artists = r0_json['artists']['artist']
r0_df = pd.DataFrame(r0_artists)
r0_df['name']
# Out:
# 0          The Weeknd
# 1        Taylor Swift
# 2                 SZA
# 3             Rihanna
# 4      Kendrick Lamar
#             ...
# 495        Bo Burnham
# 496         Sean Paul
# 497    Lynyrd Skynyrd
# 498        Jhené Aiko
# 499          Pavement
# Name: name, Length: 500, dtype: object

# %%
pop_artists_list = r0_df['name'].values.tolist()

# %%
pop_artists_list
# Out:
# ['The Weeknd',
#  'Taylor Swift',
#  'SZA',
#  'Rihanna',
#  'Kendrick Lamar',
#  'Kanye West',
#  'Drake',
#  'Lana Del Rey',
#  'Arctic Monkeys',
#  'pinkpantheress',
#  'Gorillaz',
#  'Tyler, the Creator',
#  'Frank Ocean',
#  'Harry Styles',
#  'Billie Eilish',
#  'Doja Cat',
#  'Lady Gaga',
#  'Ariana Grande',
#  'Beyoncé',
#  'Radiohead',
#  'Tame Impala',
#  'Coldplay',
#  'Miley Cyrus',
#  'Steve Lacy',
#  'Paramore',
#  'Childish Gambino',
#  'Eminem',
#  'The Neighbourhood',
#  'Post Malone',
#  'Joji',
#  'Bruno Mars',
#  'Metro Boomin',
#  'Nirvana',
#  'Kali Uchis',
#  'LIL UZI VERT',
#  'Mac DeMarco',
#  'Katy Perry',
#  'Mac Miller',
#  'Queen',
#  'Mitski',
#  'Jay-Z',
#  'The Beatles',
#  'Travis Scott',
#  'The Smiths',
#  'Playboi Carti',
#  'Lorde',
#  'J. Cole',
#  'Calvin Harris',
#  'xxxtentacion',
#  'Olivia Rodrigo',
#  'Sam Smith',
#  'A$AP Rocky',
#  'Nicki Minaj',
#  'Adele',
#  'The Strokes',
#  'Clairo',
#  'Dua Lipa',
#  'Fleetwood Mac',
#  'Maroon 5',
#  'Linkin Park',
#  'The Cure',
#  'Justin Bieber',
#  'TV Girl',
#  'Baby Keem',
#  'Future',
#  'Michael Jackson',
#  'Pink Floyd',
#  'Cigarettes After Sex',
#  'Imagine Dragons',
#  'David Guetta',
#  'beabadoobee',
#  'Deftones',
#  'Ed Sheeran',
#  'Britney Spears',
#  'Elton John',
#  'Kid Cudi',
#  'Red Hot Chili Peppers',
#  'The 1975',
#  'Beach House',
#  'NewJeans',
#  'Phoebe Bridgers',
#  'Daft Punk',
#  'Juice WRLD',
#  '21 Savage',
#  'Lil Nas X',
#  'Conan Gray',
#  'Shakira',
#  'Foo Fighters',
#  'David Bowie',
#  'My Chemical Romance',
#  'ABBA',
#  'Green Day',
#  'BTS',
#  'One Direction',
#  'Men I Trust',
#  'Panic! at the Disco',
#  'Halsey',
#  'Trippie Redd',
#  'Lil Yachty',
#  'Twenty One Pilots',
#  'Fall Out Boy',
#  'Don Toliver',
#  'Pixies',
#  'The Killers',
#  'Cage the Elephant',
#  'Metallica',
#  'MGMT',
#  'Charli XCX',
#  'Miguel',
#  'TWICE',
#  'Hozier',
#  'Marina',
#  'Lizzo',
#  'OutKast',
#  'Black Eyed Peas',
#  'System of a Down',
#  'Daniel Caesar',
#  'd4vd',
#  'OneRepublic',
#  'The Smashing Pumpkins',
#  'yeat',
#  'Brent Faiyaz',
#  'Skrillex',
#  'Selena Gomez',
#  'ICE SPICE',
#  'LIL PEEP',
#  'Bad Bunny',
#  'Weezer',
#  'Madonna',
#  'Rosalía',
#  'Tears for Fears',
#  'BLACKPINK',
#  'Girl In Red',
#  'Lil Wayne',
#  'Melanie Martinez',
#  'Nelly Furtado',
#  'Grimes',
#  'The Rolling Stones',
#  'The Kid Laroi',
#  'MF DOOM',
#  'Shawn Mendes',
#  'Glass Animals',
#  'BROCKHAMPTON',
#  'Rex Orange County',
#  'Avril Lavigne',
#  'Demi Lovato',
#  'Led Zeppelin',
#  'Raye',
#  'Muse',
#  'Slipknot',
#  'Alex G',
#  'Sufjan Stevens',
#  'DJ Khaled',
#  'Wallows',
#  'Willow',
#  'Depeche Mode',
#  'Lil Baby',
#  '5 Seconds of Summer',
#  'Chris Brown',
#  'Florence + the Machine',
#  'Tove Lo',
#  'Red Velvet',
#  'Blur',
#  'Joey Bada$$',
#  'Thundercat',
#  'Sabrina Carpenter',
#  'The Notorious B.I.G.',
#  'Pop Smoke',
#  'Khalid',
#  'Tory Lanez',
#  'Kate Bush',
#  'Caroline Polachek',
#  'Megan Thee Stallion',
#  'Marshmello',
#  '2Pac',
#  'blink-182',
#  'Denzel Curry',
#  'omar apollo',
#  'Bring Me the Horizon',
#  'Justin Timberlake',
#  'Billy Joel',
#  'LE SSERAFIM',
#  'Young Thug',
#  '$uicideboy$',
#  'Black Sabbath',
#  'Summer Walker',
#  'Hotel Ugly',
#  'Cocteau Twins',
#  'P!nk',
#  '50 Cent',
#  'Cults',
#  'Labrinth',
#  'Tiësto',
#  'Sia',
#  'Måneskin',
#  'Oasis',
#  'Charlie Puth',
#  'Mariah Carey',
#  'Aphex Twin',
#  'Pitbull',
#  'Kesha',
#  'Amy Winehouse',
#  'TOMORROW X TOGETHER',
#  'Vansire',
#  'Lizzy McAlpine',
#  'Logic',
#  'Stephen Sanchez',
#  'Bee Gees',
#  'Niall Horan',
#  'Oliver Tree',
#  'Avicii',
#  'Duster',
#  'Ellie Goulding',
#  'Carly Rae Jepsen',
#  'Bizarrap',
#  'Talking Heads',
#  'PARTYNEXTDOOR',
#  'Nas',
#  'Kodak Black',
#  'The Cranberries',
#  'Troye Sivan',
#  'Joy Division',
#  'The Chainsmokers',
#  'Mazzy Star',
#  'Chief Keef',
#  'Gunna',
#  'Foster the People',
#  'Madvillain',
#  'Dominic Fike',
#  'Zayn',
#  'Eyedress',
#  'Bon Iver',
#  'Jack Harlow',
#  'VACATIONS',
#  "Guns N' Roses",
#  'Cardi B',
#  'Migos',
#  'Mother Mother',
#  'Dr. Dre',
#  'Pharrell Williams',
#  'Pierce The Veil',
#  'Jid',
#  'JVKE',
#  'Korn',
#  'M83',
#  'Camila Cabello',
#  'Frank Sinatra',
#  'The Police',
#  'The White Stripes',
#  'Matt Maltese',
#  'AC/DC',
#  'Rina Sawayama',
#  'Chase Atlantic',
#  'A BOOGIE WIT DA HOODIE',
#  'Pearl Jam',
#  'The Doors',
#  'Earl Sweatshirt',
#  'Ive',
#  'Gwen Stefani',
#  'Usher',
#  'The Offspring',
#  'JPEGMAFIA',
#  'The Clash',
#  'Stevie Wonder',
#  'Creedence Clearwater Revival',
#  'The Alchemist',
#  'The Marías',
#  'Aerosmith',
#  'New Order',
#  'Elliott Smith',
#  'Lord Huron',
#  'Cavetown',
#  'Aminé',
#  'Ice Cube',
#  'Slowdive',
#  'Polo G',
#  'The Lumineers',
#  'The Velvet Underground',
#  'Meghan Trainor',
#  'bôa',
#  'STAYC',
#  'The Beach Boys',
#  'Jimi Hendrix',
#  'Westside Gunn',
#  'ScHoolboy Q',
#  'FKA twigs',
#  'Crystal Castles',
#  'Surf Curse',
#  'SKI MASK THE SLUMP GOD',
#  'Mark Ronson',
#  'Ghost',
#  'Björk',
#  'alt-J',
#  'My Bloody Valentine',
#  'Karol G',
#  'Limp Bizkit',
#  'Flo Rida',
#  'Gracie Abrams',
#  'Vance Joy',
#  'Swedish House Mafia',
#  'Car Seat Headrest',
#  '(G)I-DLE',
#  'Elvis Presley',
#  'Blackbear',
#  'Lauv',
#  'Fiona Apple',
#  'Current Joys',
#  'Jason Derulo',
#  'Central Cee',
#  'Kings of Leon',
#  'Two Door Cinema Club',
#  'Tom Odell',
#  'Rae Sremmurd',
#  'Marvin Gaye',
#  'Timbaland',
#  'R.E.M.',
#  'Bladee',
#  'Snoop Dogg',
#  'LUCKI',
#  'STRAY KIDS',
#  'Freddie Dredd',
#  'DJ Snake',
#  'Big Sean',
#  'Yot Club',
#  'Faye Webster',
#  'Itzy',
#  'Blondie',
#  'A$AP Ferg',
#  'Alice in Chains',
#  'Yung Lean',
#  'Vince Staples',
#  'Machine Gun Kelly',
#  'Daryl Hall & John Oates',
#  'Destroy Lonely',
#  'Bryson Tiller',
#  'Bon Jovi',
#  'NAV',
#  'COI LERAY',
#  'Azealia Banks',
#  'Earth, Wind & Fire',
#  'aespa',
#  'Major Lazer',
#  'Rammstein',
#  'The walters',
#  'Ava Max',
#  'Queens of the Stone Age',
#  'Zedd',
#  'Dayglow',
#  'A Tribe Called Quest',
#  'Dove Cameron',
#  'Sade',
#  '100 gecs',
#  "Her's",
#  'Giveon',
#  'Rage Against the Machine',
#  'Roddy Ricch',
#  'The Mamas & the Papas',
#  'Lewis Capaldi',
#  'Suki Waterhouse',
#  'Eagles',
#  'Lil Tecca',
#  'Dreamville',
#  'Blood Orange',
#  'J-Hope',
#  'Japanese Breakfast',
#  'Franz Ferdinand',
#  'J Balvin',
#  'Pusha T',
#  'Gucci Mane',
#  'Salvia Palth',
#  'Still Woozy',
#  'Flume',
#  'Wiz Khalifa',
#  'Billy Idol',
#  'Aurora',
#  'U2',
#  'Loona',
#  'Boygenius',
#  'Weyes Blood',
#  'Disclosure',
#  'Seventeen',
#  'Bob Dylan',
#  'Benny Blanco',
#  'Big Thief',
#  'Alvvays',
#  'Meek Mill',
#  'Freddie Gibbs',
#  'Lykke Li',
#  'Little Mix',
#  'M.I.A.',
#  'Young Nudy',
#  'Alicia Keys',
#  'The Cardigans',
#  'Martin Garrix',
#  'Evanescence',
#  'Nine Inch Nails',
#  'Selena Gomez & the Scene',
#  'NLE Choppa',
#  'Rema',
#  'Sonic Youth',
#  'Kids See Ghosts',
#  'Declan Mckenna',
#  'Electric Light Orchestra',
#  'Ken Carson',
#  'John Lennon',
#  'IU',
#  'Kaytranada',
#  'Vampire Weekend',
#  'a-ha',
#  'Death Grips',
#  'Whitney Houston',
#  'All Time Low',
#  'The Goo Goo Dolls',
#  'Isaiah Rashad',
#  'Yeah Yeah Yeahs',
#  'Beach Weather',
#  'Bastille',
#  'NF',
#  'ENHYPEN',
#  'Three Days Grace',
#  'Exo',
#  "Destiny's Child",
#  'Simon & Garfunkel',
#  'DaBaby',
#  'NCT 127',
#  'Clean Bandit',
#  'Jonas Brothers',
#  'Victoria Monét',
#  'Fergie',
#  'John Mayer',
#  'Toto',
#  'Beach Bunny',
#  'Dire Straits',
#  'Ashnikko',
#  'Jaden',
#  'Kelly Clarkson',
#  'Neutral Milk Hotel',
#  'slowthai',
#  'Kygo',
#  'Yves Tumor',
#  'Bibi',
#  'Tay-K',
#  'Mr.kitty',
#  'Ethel Cain',
#  'Bones',
#  'BØRNS',
#  'Crumb',
#  'Prince',
#  'Keane',
#  'Kehlani',
#  'YoungBoy Never Broke Again',
#  'Anitta',
#  'Gotye',
#  'Bob Marley & The Wailers',
#  'Ricky Montgomery',
#  'XG',
#  'Beastie Boys',
#  'Peach Pit',
#  'Arcade Fire',
#  'Strawberry Guy',
#  'Diplo',
#  'Macklemore & Ryan Lewis',
#  'Vundabar',
#  'Beck',
#  'Soundgarden',
#  'The Black Keys',
#  'Falling in Reverse',
#  'Jennifer Lopez',
#  'Cafuné',
#  'Kiss',
#  'Kim Petras',
#  'Johnny Cash',
#  'Chance the Rapper',
#  'Mavi',
#  'Empire of the Sun',
#  'Akon',
#  'Daddy Yankee',
#  "Girls' Generation",
#  'Cuco',
#  'B.o.B',
#  'Cochise',
#  'Machine Girl',
#  'James Arthur',
#  'Lisa',
#  'Offset',
#  'Iron Maiden',
#  'The Backseat Lovers',
#  'Djo',
#  'Anderson .Paak',
#  'ThxSoMch',
#  'Quavo',
#  'Zara Larsson',
#  'George Michael',
#  'Patrick Watson',
#  'Kordhell',
#  'Bo Burnham',
#  'Sean Paul',
#  'Lynyrd Skynyrd',
#  'Jhené Aiko',
#  'Pavement']

# %%
frames = [pd.DataFrame(r.json()['artists']['artist']) for r in responses]
artists = pd.concat(frames)
artists.head()
# Out:
#              name   playcount listeners                                  mbid  \
# 0      The Weeknd   427450134   3125939  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 1    Taylor Swift  1185775625   3818727  20244d07-534f-4eff-b4d4-930878889970
# 2             SZA   174163219   1728754  272989c8-5535-492d-a25c-9f58803e027f
# 3         Rihanna   308530183   6011573  db36a76f-4cdf-43ac-8cd0-5e48092d2bae
# 4  Kendrick Lamar   352334970   2885043  381086ea-f511-4aba-bdf9-71c753dc5077
#
#                                         url streamable  \
# 0      https://www.last.fm/music/The+Weeknd          0
# 1    https://www.last.fm/music/Taylor+Swift          0
# 2             https://www.last.fm/music/SZA          0
# 3         https://www.last.fm/music/Rihanna          0
# 4  https://www.last.fm/music/Kendrick+Lamar          0
#
#                                                image
# 0  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 1  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 2  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 3  [{'#text': 'https://lastfm.freetls.fastly.net/...
# 4  [{'#text': 'https://lastfm.freetls.fastly.net/...

# %%
artists = artists.drop('image', axis=1)
artists.head()
# Out:
#              name   playcount listeners                                  mbid  \
# 0      The Weeknd   427450134   3125939  c8b03190-306c-4120-bb0b-6f2ebfc06ea9
# 1    Taylor Swift  1185775625   3818727  20244d07-534f-4eff-b4d4-930878889970
# 2             SZA   174163219   1728754  272989c8-5535-492d-a25c-9f58803e027f
# 3         Rihanna   308530183   6011573  db36a76f-4cdf-43ac-8cd0-5e48092d2bae
# 4  Kendrick Lamar   352334970   2885043  381086ea-f511-4aba-bdf9-71c753dc5077
#
#                                         url streamable
# 0      https://www.last.fm/music/The+Weeknd          0
# 1    https://www.last.fm/music/Taylor+Swift          0
# 2             https://www.last.fm/music/SZA          0
# 3         https://www.last.fm/music/Rihanna          0
# 4  https://www.last.fm/music/Kendrick+Lamar          0

# %%
artists.info()
artists.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14500 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        14500 non-null  object
#  1   playcount   14500 non-null  object
#  2   listeners   14500 non-null  object
#  3   mbid        14500 non-null  object
#  4   url         14500 non-null  object
#  5   streamable  14500 non-null  object
# dtypes: object(6)
# memory usage: 793.0+ KB
#              name playcount listeners   mbid  \
# count       14500     14500     14500  14500
# unique       9998      9998      9916   5563
# top     Sheck Wes    704777    493360
# freq            3         3         4   6447
#
#                                         url streamable
# count                                 14500      14500
# unique                                 9998          1
# top     https://www.last.fm/music/Sheck+Wes          0
# freq                                      3      14500

# %%
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 648         0.778   0.737    7    -7.861     1       0.2510      0.000310
# 622         0.756   0.632    7    -8.441     1       0.1640      0.000165
# 623         0.677   0.614    8    -5.935     1       0.0732      0.000364
# 624         0.572   0.693    8    -7.492     1       0.2690      0.100000
# 625         0.692   0.678    2    -6.517     1       0.0840      0.006530
# ..            ...     ...  ...       ...   ...          ...           ...
# 17          0.513   0.692    9    -6.030     1       0.0398      0.366000
# 18          0.570   0.510    5   -13.850     1       0.7650      0.718000
# 19          0.465   0.260    0    -8.179     0       0.0310      0.475000
# 10          0.787   0.598    1    -7.457     1       0.2120      0.573000
# 0           0.247   0.299    9    -6.083     1       0.0315      0.899000
#
#      instrumentalness  liveness  valence  ...  \
# 648          0.000000    0.2760    0.582  ...
# 622          0.000886    0.0963    0.505  ...
# 623          0.001580    0.1070    0.643  ...
# 624          0.000000    0.0426    0.757  ...
# 625          0.000002    0.1390    0.610  ...
# ..                ...       ...      ...  ...
# 17           0.000000    0.1510    0.534  ...
# 18           0.000467    0.0979    0.138  ...
# 19           0.000000    0.1380    0.259  ...
# 10           0.000002    0.1030    0.820  ...
# 0            0.000000    0.1310    0.172  ...
#
#                                       uri  \
# 648  spotify:track:1B4iEymNy6FyU2I39ujzVw
# 622  spotify:track:3U3Ff8ZvL6oEu1r98gCCWW
# 623  spotify:track:6N2E4G9gU2yxJYJndMPsYE
# 624  spotify:track:1Q29dre9FCspRSarHziizl
# 625  spotify:track:1vSCj9zmP1zRD1D5ruLUkR
# ..                                    ...
# 17   spotify:track:1p9R4HF2WGtZDISBxMwF3R
# 18   spotify:track:3c1YCQvr720s61gHPgtkv8
# 19   spotify:track:18zQTt3ifDv6iLni2YuXMg
# 10   spotify:track:02dF3qjpgTpmPCBKo72C06
# 0    spotify:track:6sCvvleqKbeyOkQDieBYgp
#
#                                             track_href  \
# 648  https://api.spotify.com/v1/tracks/1B4iEymNy6Fy...
# 622  https://api.spotify.com/v1/tracks/3U3Ff8ZvL6oE...
# 623  https://api.spotify.com/v1/tracks/6N2E4G9gU2yx...
# 624  https://api.spotify.com/v1/tracks/1Q29dre9FCsp...
# 625  https://api.spotify.com/v1/tracks/1vSCj9zmP1zR...
# ..                                                 ...
# 17   https://api.spotify.com/v1/tracks/1p9R4HF2WGtZ...
# 18   https://api.spotify.com/v1/tracks/3c1YCQvr720s...
# 19   https://api.spotify.com/v1/tracks/18zQTt3ifDv6...
# 10   https://api.spotify.com/v1/tracks/02dF3qjpgTpm...
# 0    https://api.spotify.com/v1/tracks/6sCvvleqKbey...
#
#                                           analysis_url duration_ms  \
# 648  https://api.spotify.com/v1/audio-analysis/1B4i...      217187
# 622  https://api.spotify.com/v1/audio-analysis/3U3F...      246960
# 623  https://api.spotify.com/v1/audio-analysis/6N2E...      251133
# 624  https://api.spotify.com/v1/audio-analysis/1Q29...      208107
# 625  https://api.spotify.com/v1/audio-analysis/1vSC...      260067
# ..                                                 ...         ...
# 17   https://api.spotify.com/v1/audio-analysis/1p9R...      222000
# 18   https://api.spotify.com/v1/audio-analysis/3c1Y...      160480
# 19   https://api.spotify.com/v1/audio-analysis/18zQ...      213333
# 10   https://api.spotify.com/v1/audio-analysis/02dF...      224747
# 0    https://api.spotify.com/v1/audio-analysis/6sCv...      196520
#
#     time_signature                                         track_name  \
# 648              4                              Pon De Replay - Remix
# 622              4                                      Pon de Replay
# 623              4                                    Here I Go Again
# 624              4                       If It's Lovin' That You Want
# 625              4                     You Don't Love Me (No, No, No)
# ..             ...                                                ...
# 17               1                                 No Digas Mi Nombre
# 18               3                                          Mi Pueblo
# 19               4                                         Born Again
# 10               4                               Laayli' kuxa'ano'one
# 0                4  Lift Me Up - From Black Panther: Wakanda Forev...
#
#                                             album_name  \
# 648                                   Music Of The Sun
# 622                                   Music Of The Sun
# 623                                   Music Of The Sun
# 624                                   Music Of The Sun
# 625                                   Music Of The Sun
# ..                                                 ...
# 17   Black Panther: Wakanda Forever - Music From an...
# 18   Black Panther: Wakanda Forever - Music From an...
# 19   Black Panther: Wakanda Forever - Music From an...
# 10   Black Panther: Wakanda Forever - Music From an...
# 0    Black Panther: Wakanda Forever - Music From an...
#
#                                       short_album_name release_date  \
# 648                                   Music Of The Sun   2005-08-29
# 622                                   Music Of The Sun   2005-08-29
# 623                                   Music Of The Sun   2005-08-29
# 624                                   Music Of The Sun   2005-08-29
# 625                                   Music Of The Sun   2005-08-29
# ..                                                 ...          ...
# 17   Black Panther: Wakanda Forever - Music From an...   2022-11-11
# 18   Black Panther: Wakanda Forever - Music From an...   2022-11-11
# 19   Black Panther: Wakanda Forever - Music From an...   2022-11-11
# 10   Black Panther: Wakanda Forever - Music From an...   2022-11-11
# 0    Black Panther: Wakanda Forever - Music From an...   2022-11-11
#
#                    album_id
# 648  4FyGpObwABjn0o8Tdp7AZz
# 622  19UbDbyaYRW1U7lBMYO9F2
# 623  19UbDbyaYRW1U7lBMYO9F2
# 624  19UbDbyaYRW1U7lBMYO9F2
# 625  19UbDbyaYRW1U7lBMYO9F2
# ..                      ...
# 17   06RK0wX4GqHcxBtHlVoGH5
# 18   06RK0wX4GqHcxBtHlVoGH5
# 19   06RK0wX4GqHcxBtHlVoGH5
# 10   06RK0wX4GqHcxBtHlVoGH5
# 0    06RK0wX4GqHcxBtHlVoGH5
#
# [645 rows x 23 columns]

# %%
import datetime
import billboard
import pandas as pd
from collections import defaultdict

# Initiate the dictionary to store artist data
artist_data = defaultdict(int)

# Set the date for 5 years ago
date = datetime.datetime.now() - datetime.timedelta(weeks=20)

# Loop over each week for the past 5 years
while date < datetime.datetime.now():
    # Fetch the top 100 songs for this week
    chart = billboard.ChartData('hot-100', date=date.strftime('%Y-%m-%d'))

    # Loop over each song in the chart
    for song in chart:
        # Loop over each artist for the song (songs can have multiple artists)
        for artist in song.artist.split(' Featuring '):
            # Increment the number of weeks this artist has been in the top 100
            artist_data[artist] += 1

    # Increment the date by one week
    date += datetime.timedelta(weeks=1)

# %%
# Convert the artist data into a DataFrame
df = pd.DataFrame(list(artist_data.items()), columns=['Artist', 'WeeksInTop100'])

# Sort the DataFrame by the number of weeks in the top 100
df = df.sort_values('WeeksInTop100', ascending=False)

# Print the top 10 artists
print(df.head(10))
# Out:
#                 Artist  WeeksInTop100
# 42       Morgan Wallen            225
# 10                 SZA            145
# 61          Luke Combs             61
# 7         Taylor Swift             54
# 19   Drake & 21 Savage             53
# 100           Lil Baby             47
# 60       Lainey Wilson             35
# 38          Zach Bryan             35
# 47        Lil Uzi Vert             27
# 54    Bailey Zimmerman             26

# %%
import datetime
import billboard
import pandas as pd
from collections import defaultdict

# Initiate the dictionary to store artist data
artist_data = defaultdict(int)

# Set the date for 5 years ago
date = datetime.datetime.now() - datetime.timedelta(weeks=5*52)

# Loop over each week for the past 5 years
while date < datetime.datetime.now():
    # Fetch the top 100 songs for this week
    chart = billboard.ChartData('hot-100', date=date.strftime('%Y-%m-%d'))

    # Loop over each song in the chart
    for song in chart:
        # Loop over each artist for the song (songs can have multiple artists)
        for artist in song.artist.split(' Featuring '):
            # Increment the number of weeks this artist has been in the top 100
            artist_data[artist] += 1

    # Increment the date by one week
    date += datetime.timedelta(weeks=1)

# Convert the artist data into a DataFrame
df = pd.DataFrame(list(artist_data.items()), columns=['Artist', 'Total Chart Entries Weekly for Past 5 years'])

# Sort the DataFrame by the number of weeks in the top 100
df = df.sort_values('Total Chart Entries Weekly for Past 5 years', ascending=False)

# Print the top 10 artists
print(df.head(10))
# Out:
#             Artist  Total Chart Entries Weekly for Past 5 years
# 0            Drake                                          846
# 54   Morgan Wallen                                          638
# 78        Lil Baby                                          504
# 33    Taylor Swift                                          437
# 37      Luke Combs                                          379
# 2      Post Malone                                          378
# 523       Doja Cat                                          378
# 367         DaBaby                                          337
# 397            SZA                                          310
# 178  Billie Eilish                                          281

# %%
topten_df = (df.head(10))

# %%
topten_df['Artist']
# Out:
# 0              Drake
# 54     Morgan Wallen
# 78          Lil Baby
# 33      Taylor Swift
# 37        Luke Combs
# 2        Post Malone
# 523         Doja Cat
# 367           DaBaby
# 397              SZA
# 178    Billie Eilish
# Name: Artist, dtype: object

# %%
topten_list = topten_df['Artist'].values.tolist()

# %%
topten_list
# Out:
# ['Drake',
#  'Morgan Wallen',
#  'Lil Baby',
#  'Taylor Swift',
#  'Luke Combs',
#  'Post Malone',
#  'Doja Cat',
#  'DaBaby',
#  'SZA',
#  'Billie Eilish']

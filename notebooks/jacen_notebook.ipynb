# %% [markdown]
# # Jacen's notebook (for now)
# ## Discovering the listening patterns of users from different countries
# Basically I will just take the top 50 songs from each country and get the average value of the audio features for all the songs. Since one of the broad aims of our project is to discover the listening patterns of Spotify users, I thought it would be interesting to take a geographical approach.<br><br> What is helpful about the audio features provided by the Spotify API is that they have been quantified, which means it is easy to just get the mean value of the audio features for all the top 50 songs in a country. Then I can get a representative sample of what kind of songs users in that country like to listen to.<br><br> One thing I wish to do later is try to weigh the audio features by the popularity of the song to make it more reflective of the country's users' tastes. But for now I will just get the mean for each country and then we can do some analysis on that.

# %%
# I had to make my own dictionary of each country's daily top 50 playlists
# because I can't just scrape the data from the website or using the API
# I will put this in a .py file later and import it into this notebook

top_50_playlists = [
    {'country' : 'Argentina', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbMMy2roB9myp?si=d47713136c474c53'}, 
    {'country' : 'Australia', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJPcfkRz0wJ0?si=73bda9551f9345ca'},
    {'country' : 'Austria', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKNHh6NIXu36?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Belarus', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbIYfjSLbWr4V?si=d4b611bdb7454131'},
    {'country' : 'Belgium', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJNSeeHswcKB?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Bolivia', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJqfMFK4d691?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Brazil', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbMXbN3EUUhlg?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Bulgaria', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbNfM2w2mq1B8?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Canada', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKj23U1GF4IR?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Chile', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbL0GavIqMTeb?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Colombia', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbOa2lmxNORXQ?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Costa Rica', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbMZAjGMynsQX?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Czech Republic', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbIP3c3fqVrJY?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Denmark', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbL3J0k32lWnN?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Dominican Republic', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKAbrMR8uuf7?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Ecuador', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJlM6nvL1nD1?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Egypt', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJ6IpvItkve3?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'El Salvador', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLxoIml4MYkT?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Estonia', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLesry2Qw2xS?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Finland', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbMxcczTSoGwZ?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'France', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbIPWwFssbupI?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Germany', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJiZcmkrIHGU?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Greece', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJqfMFK4d691?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Guatemala', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLy5tBFyQvd4?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Honduras', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJp9wcIM9Eo5?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Hong Kong', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLwpL8TjsxOG?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Hungary', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbNHwMxAkvmF8?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Iceland', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKMzVsSGQ49S?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'India', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLZ52XmnySJg?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Indonesia', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbObFQZ3JLcXt?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Ireland', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKM896FDX8L1?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Israel', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJ6IpvItkve3?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Italy', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbIQnj7RRhdSX?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Japan', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKXQ4mDTEBXq?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Kazakhstan', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbM472oKPNKzS?si=1d35f5f2f10247ac'},
    {'country' : 'Latvia', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJWuzDrTxbKS?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Lithuania', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbMx56Rdq5lwc?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Luxembourg', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKGcyg6TFGx6?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Malaysia', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJlfUljuZExa?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Mexico', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbO3qyFxbkOE1?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Morocco', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJU9eQpX8gPT?si=9cc564128c8740bb'},
    {'country' : 'Netherlands', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKCF6dqVpDkS?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'New Zealand', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbM8SIrkERIYl?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Nicaragua', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbISk8kxnzfCq?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Nigeria', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKY7jLzlJ11V?si=af63b882ab484c97'},
    {'country' : 'Norway', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJvfa0Yxg7E7?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Pakistan', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJkgIdfsJyTw?si=1a04c48180a248f1'},
    {'country' : 'Panama', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKypXHVwk1f0?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Paraguay', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbNOUPGj7tW6T?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Peru', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJfdy5b0KP7W?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Philippines', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbNBz9cRCSFkY?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Poland', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbN6itCcaL3Tt?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Portugal', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKyJS56d1pgi?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Romania', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbNZbJ6TZelCq?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Saudi Arabia', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLrQBcXqUtaC?si=5834de01ea1841f2'},
    {'country' : 'Singapore', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbK4gjvS1FjPY?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Slovakia', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKIVTPX9a2Sb?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'South Africa', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbMH2jvi6jvjk?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'South Korea', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbNxXF4SkHj9F?si=696c7ba21cb74699'},
    {'country' : 'Spain', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbNFJfN1Vw8d9?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Sweden', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLoATJ81JYXz?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Switzerland', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbJiyhoAPEfMK?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Taiwan', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbMnZEatlMSiu?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Thailand', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbMnz8KIWsvf9?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Turkey', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbIVYVBNw9D5K?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Ukraine', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbKkidEfWYRuD?si=aa038fe2c2104c7f'},
    {'country' : 'United Arab Emirates', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbM4UZuIrvHvA?si=67ddedd2245644d6'},
    {'country' : 'United Kingdom', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLnolsZ8PSNw?si=c5fac239cb7b4619'},
    {'country' : 'United States', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLRQDuF5jeBp?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Uruguay', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbMJJi3wgRbAy?si=3b1b0b6b1b1b4c8a'},
    {'country' : 'Venezuela', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbNLrliB10ZnX?si=23ef2b0d263b455d'},
    {'country' : 'Vietnam', 'url' : 'https://open.spotify.com/playlist/37i9dQZEVXbLdGSmz6xilI?si=ea2772c536e74935'}
]

# %%
# first I need to import the necessary packages and define a function

import requests
import pandas as pd
# reminder to self not to add the access token to github!!!
access_token = 'BQC8ALsLkyCnVg5hJBT4sPMnPZpGRCu9mmY2ngAooN7TVDnTVpT8PM8VktVqZjo-6j6uSTRv_sZXhY-0RzwihssIm5fAVAxrq2pqAbTYp9wbSyA6lTg50JFn0uzkV9kOoJ1R5_hNbGSWtHNCNpM0Az6VsoPTO9UXQTxhT3Xyz-r-ptx2cA'
Authorization = 'Bearer ' + access_token

def get_features(playlist):
    '''
    playlist: dictionary with keys 'country' and 'url'
    returns: dataframe with audio features for each track in the playlist
    '''
    playlist_id = playlist['url'].strip('https://open.spotify.com/playlist/').split('?')[0]
    playlist_tracks_url = 'https://api.spotify.com/v1/playlists/' + playlist_id +'/tracks'
    tracks = requests.get(playlist_tracks_url, headers={'Authorization': Authorization})
    # this is so I know what error I am getting if the code doesn't work for some reason
    if tracks.status_code != 200:
        raise Exception('Error: ' + tracks.text)
    else:
        track_uris = [track['track']['uri'].replace('spotify:track:','') for track in tracks.json()['items']]
        ids = '%2C'.join(track_uris)
        track_names = [track['track']['name'] for track in tracks.json()['items']]
        audio_features_url = 'https://api.spotify.com/v1/audio-features?ids=' + ids
        response = requests.get(audio_features_url, headers={'ids': ids, 'Authorization': Authorization})
        df = pd.DataFrame(data = response.json()['audio_features'], index = track_names)
        return df

# %%
# first I want to see what the function returns for one playlist
df_argentina = get_features(top_50_playlists[0])
df_argentina
# Out:
#                                                 danceability  energy  key  \
# En La Intimidad | CROSSOVER #1                         0.804   0.555    1
# M.A (Mejores Amigos)                                   0.746   0.729    7
# TQG                                                    0.720   0.630    4
# Ya No Vuelvas (Versión Cuarteto)                       0.736   0.900    1
# MERCHO                                                 0.838   0.790    6
# Cupido                                                 0.913   0.584    9
# Rara Vez                                               0.838   0.708    5
# Yandel 150                                             0.783   0.729    6
# Pobre Corazón                                          0.463   0.840   10
# Arcángel: Bzrp Music Sessions, Vol. 54                 0.716   0.780   11
# Te Escapas De Mis Brazos (Remix)                       0.722   0.689    0
# Muñecas                                                0.688   0.712   10
# Shakira: Bzrp Music Sessions, Vol. 53                  0.778   0.632    2
# Pa’ la Selección                                       0.605   0.572   11
# Quiero Creer                                           0.678   0.624    6
# PUNTO G                                                0.751   0.761   11
# Marisola - Remix                                       0.765   0.872    1
# Hey Mor                                                0.901   0.589    1
# La Bachata                                             0.835   0.679    7
# Coco Chanel                                            0.683   0.764    2
# Feliz Cumpleaños Ferxxo                                0.865   0.573    5
# Vida Gangster                                          0.693   0.756    4
# Sesión - 6                                             0.917   0.690    7
# Milagrosa                                              0.899   0.442    2
# PLAYA DEL INGLÉS                                       0.793   0.736    7
# Dos Besitos                                            0.864   0.667    5
# Si No Te Tengo / Ángel / Aquello Que Pasó              0.419   0.711   11
# Tu Turrito                                             0.838   0.545    9
# Costumbres - Vivo                                      0.520   0.801    9
# ARRANCARMELO                                           0.654   0.354    5
# Quevedo: Bzrp Music Sessions, Vol. 52                  0.621   0.782    2
# CHORRITO PA LAS ANIMAS                                 0.743   0.831    8
# CALLEJERO FINO | DJ TAO Turreo Sessions #723           0.774   0.877   10
# Amanecemos                                             0.494   0.504    5
# Normal                                                 0.709   0.560    4
# Flowers                                                0.707   0.681    0
# Le doy perreo                                          0.872   0.544   10
# Butakera                                               0.871   0.563    1
# ADIÓS                                                  0.747   0.765    9
# VISTA AL MAR                                           0.759   0.561    0
# LA NENA DE ARGENTINA                                   0.531   0.580    5
# Universo Paralelo                                      0.619   0.739    4
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix         0.837   0.750    9
# WANDA                                                  0.724   0.631    4
# DISCOTEKA (feat. Locura Mix)                           0.822   0.519    9
# BESO                                                   0.768   0.644    5
# Que Te Vaya Bien                                       0.675   0.460    4
# El Merengue                                            0.775   0.677    8
# MORNING                                                0.811   0.462   10
# Te Mentiría                                            0.651   0.731    7
#
#                                                 loudness  mode  speechiness  \
# En La Intimidad | CROSSOVER #1                    -4.991     1       0.1070
# M.A (Mejores Amigos)                              -5.855     1       0.0630
# TQG                                               -3.547     0       0.2770
# Ya No Vuelvas (Versión Cuarteto)                  -4.575     1       0.0825
# MERCHO                                            -1.602     0       0.1080
# Cupido                                            -5.263     1       0.2230
# Rara Vez                                          -4.668     0       0.1660
# Yandel 150                                        -3.549     0       0.0691
# Pobre Corazón                                     -4.781     0       0.0475
# Arcángel: Bzrp Music Sessions, Vol. 54            -3.495     0       0.2970
# Te Escapas De Mis Brazos (Remix)                  -5.074     1       0.0551
# Muñecas                                           -4.791     0       0.0826
# Shakira: Bzrp Music Sessions, Vol. 53             -5.600     0       0.0493
# Pa’ la Selección                                  -6.060     0       0.0435
# Quiero Creer                                      -3.712     1       0.0589
# PUNTO G                                           -4.113     0       0.1500
# Marisola - Remix                                  -5.863     1       0.0498
# Hey Mor                                           -6.713     0       0.2890
# La Bachata                                        -5.329     0       0.0364
# Coco Chanel                                       -5.995     1       0.0441
# Feliz Cumpleaños Ferxxo                           -5.501     1       0.0678
# Vida Gangster                                     -5.209     0       0.0477
# Sesión - 6                                        -4.997     1       0.2290
# Milagrosa                                         -8.931     1       0.2910
# PLAYA DEL INGLÉS                                  -3.254     0       0.0469
# Dos Besitos                                       -4.617     0       0.0833
# Si No Te Tengo / Ángel / Aquello Que Pasó         -4.083     0       0.0488
# Tu Turrito                                        -6.100     0       0.0604
# Costumbres - Vivo                                 -6.617     0       0.0382
# ARRANCARMELO                                      -7.358     1       0.0738
# Quevedo: Bzrp Music Sessions, Vol. 52             -5.548     1       0.0440
# CHORRITO PA LAS ANIMAS                            -4.042     0       0.0584
# CALLEJERO FINO | DJ TAO Turreo Sessions #723      -4.054     1       0.0623
# Amanecemos                                        -6.242     1       0.1110
# Normal                                            -4.867     0       0.1710
# Flowers                                           -4.325     1       0.0668
# Le doy perreo                                     -7.097     0       0.3060
# Butakera                                          -6.422     1       0.0618
# ADIÓS                                             -4.184     0       0.0547
# VISTA AL MAR                                      -5.643     0       0.1310
# LA NENA DE ARGENTINA                              -4.688     0       0.1880
# Universo Paralelo                                 -5.743     1       0.1670
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix    -4.530     1       0.1590
# WANDA                                             -4.420     0       0.0686
# DISCOTEKA (feat. Locura Mix)                      -7.183     1       0.1360
# BESO                                              -6.671     0       0.1360
# Que Te Vaya Bien                                  -5.229     1       0.0528
# El Merengue                                       -4.703     0       0.0442
# MORNING                                           -7.526     0       0.4190
# Te Mentiría                                       -6.889     1       0.0549
#
#                                                 acousticness  \
# En La Intimidad | CROSSOVER #1                       0.09240
# M.A (Mejores Amigos)                                 0.29800
# TQG                                                  0.67300
# Ya No Vuelvas (Versión Cuarteto)                     0.22400
# MERCHO                                               0.43100
# Cupido                                               0.52100
# Rara Vez                                             0.17600
# Yandel 150                                           0.04920
# Pobre Corazón                                        0.04450
# Arcángel: Bzrp Music Sessions, Vol. 54               0.55000
# Te Escapas De Mis Brazos (Remix)                     0.10500
# Muñecas                                              0.02880
# Shakira: Bzrp Music Sessions, Vol. 53                0.27400
# Pa’ la Selección                                     0.14400
# Quiero Creer                                         0.27900
# PUNTO G                                              0.25100
# Marisola - Remix                                     0.17300
# Hey Mor                                              0.00302
# La Bachata                                           0.58300
# Coco Chanel                                          0.04270
# Feliz Cumpleaños Ferxxo                              0.08630
# Vida Gangster                                        0.50000
# Sesión - 6                                           0.05700
# Milagrosa                                            0.10600
# PLAYA DEL INGLÉS                                     0.08220
# Dos Besitos                                          0.24500
# Si No Te Tengo / Ángel / Aquello Que Pasó            0.05130
# Tu Turrito                                           0.09660
# Costumbres - Vivo                                    0.13200
# ARRANCARMELO                                         0.72400
# Quevedo: Bzrp Music Sessions, Vol. 52                0.01250
# CHORRITO PA LAS ANIMAS                               0.11400
# CALLEJERO FINO | DJ TAO Turreo Sessions #723         0.03040
# Amanecemos                                           0.17900
# Normal                                               0.03400
# Flowers                                              0.06320
# Le doy perreo                                        0.23300
# Butakera                                             0.56000
# ADIÓS                                                0.37400
# VISTA AL MAR                                         0.80300
# LA NENA DE ARGENTINA                                 0.09840
# Universo Paralelo                                    0.46400
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix       0.01760
# WANDA                                                0.24900
# DISCOTEKA (feat. Locura Mix)                         0.17800
# BESO                                                 0.73600
# Que Te Vaya Bien                                     0.08790
# El Merengue                                          0.03130
# MORNING                                              0.49500
# Te Mentiría                                          0.11600
#
#                                                 instrumentalness  liveness  \
# En La Intimidad | CROSSOVER #1                          0.000000    0.0699
# M.A (Mejores Amigos)                                    0.000000    0.2710
# TQG                                                     0.000000    0.0936
# Ya No Vuelvas (Versión Cuarteto)                        0.000000    0.3750
# MERCHO                                                  0.000003    0.1840
# Cupido                                                  0.000054    0.3070
# Rara Vez                                                0.000000    0.3430
# Yandel 150                                              0.000272    0.1000
# Pobre Corazón                                           0.000000    0.4430
# Arcángel: Bzrp Music Sessions, Vol. 54                  0.000000    0.1460
# Te Escapas De Mis Brazos (Remix)                        0.000000    0.0357
# Muñecas                                                 0.000000    0.3130
# Shakira: Bzrp Music Sessions, Vol. 53                   0.000000    0.0915
# Pa’ la Selección                                        0.000000    0.7210
# Quiero Creer                                            0.000000    0.1050
# PUNTO G                                                 0.000238    0.0991
# Marisola - Remix                                        0.000006    0.0749
# Hey Mor                                                 0.000237    0.0992
# La Bachata                                              0.000002    0.2180
# Coco Chanel                                             0.000000    0.0963
# Feliz Cumpleaños Ferxxo                                 0.000000    0.3050
# Vida Gangster                                           0.000047    0.1350
# Sesión - 6                                              0.000076    0.0734
# Milagrosa                                               0.000002    0.2150
# PLAYA DEL INGLÉS                                        0.000000    0.1090
# Dos Besitos                                             0.000000    0.0998
# Si No Te Tengo / Ángel / Aquello Que Pasó               0.000000    0.2430
# Tu Turrito                                              0.000000    0.0927
# Costumbres - Vivo                                       0.000000    0.9530
# ARRANCARMELO                                            0.000000    0.1340
# Quevedo: Bzrp Music Sessions, Vol. 52                   0.033000    0.2300
# CHORRITO PA LAS ANIMAS                                  0.000064    0.3500
# CALLEJERO FINO | DJ TAO Turreo Sessions #723            0.000000    0.4290
# Amanecemos                                              0.001980    0.2000
# Normal                                                  0.000000    0.3150
# Flowers                                                 0.000005    0.0322
# Le doy perreo                                           0.000000    0.2600
# Butakera                                                0.000000    0.0665
# ADIÓS                                                   0.000005    0.2020
# VISTA AL MAR                                            0.121000    0.1010
# LA NENA DE ARGENTINA                                    0.000201    0.1010
# Universo Paralelo                                       0.000000    0.2850
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix          0.000000    0.6110
# WANDA                                                   0.000000    0.2130
# DISCOTEKA (feat. Locura Mix)                            0.000000    0.0814
# BESO                                                    0.000837    0.1730
# Que Te Vaya Bien                                        0.000000    0.1650
# El Merengue                                             0.005170    0.1120
# MORNING                                                 0.000001    0.0875
# Te Mentiría                                             0.000000    0.0708
#
#                                                 valence    tempo  \
# En La Intimidad | CROSSOVER #1                    0.640   89.946
# M.A (Mejores Amigos)                              0.755   87.971
# TQG                                               0.607  179.974
# Ya No Vuelvas (Versión Cuarteto)                  0.562  149.947
# MERCHO                                            0.962   92.927
# Cupido                                            0.627  119.873
# Rara Vez                                          0.960  119.984
# Yandel 150                                        0.580  167.968
# Pobre Corazón                                     0.466   91.038
# Arcángel: Bzrp Music Sessions, Vol. 54            0.786  123.856
# Te Escapas De Mis Brazos (Remix)                  0.704   91.978
# Muñecas                                           0.852   89.930
# Shakira: Bzrp Music Sessions, Vol. 53             0.498  122.104
# Pa’ la Selección                                  0.834   84.827
# Quiero Creer                                      0.927   90.983
# PUNTO G                                           0.553   92.032
# Marisola - Remix                                  0.722   94.999
# Hey Mor                                           0.399   98.002
# La Bachata                                        0.850  124.980
# Coco Chanel                                       0.137  149.949
# Feliz Cumpleaños Ferxxo                           0.563   94.999
# Vida Gangster                                     0.530   94.884
# Sesión - 6                                        0.556   95.013
# Milagrosa                                         0.766  117.053
# PLAYA DEL INGLÉS                                  0.656  112.993
# Dos Besitos                                       0.782   96.889
# Si No Te Tengo / Ángel / Aquello Que Pasó         0.529   82.180
# Tu Turrito                                        0.428   90.023
# Costumbres - Vivo                                 0.571  103.681
# ARRANCARMELO                                      0.262   81.956
# Quevedo: Bzrp Music Sessions, Vol. 52             0.550  128.033
# CHORRITO PA LAS ANIMAS                            0.609   95.975
# CALLEJERO FINO | DJ TAO Turreo Sessions #723      0.648   92.997
# Amanecemos                                        0.459   84.916
# Normal                                            0.541  170.082
# Flowers                                           0.646  117.999
# Le doy perreo                                     0.593   98.024
# Butakera                                          0.457   88.960
# ADIÓS                                             0.514   98.012
# VISTA AL MAR                                      0.491  104.915
# LA NENA DE ARGENTINA                              0.887  169.865
# Universo Paralelo                                 0.672  149.975
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix    0.689   97.003
# WANDA                                             0.957  176.076
# DISCOTEKA (feat. Locura Mix)                      0.779   89.962
# BESO                                              0.530   95.050
# Que Te Vaya Bien                                  0.643  172.029
# El Merengue                                       0.698  124.011
# MORNING                                           0.600  108.718
# Te Mentiría                                       0.653  153.104
#
#                                                           type  \
# En La Intimidad | CROSSOVER #1                  audio_features
# M.A (Mejores Amigos)                            audio_features
# TQG                                             audio_features
# Ya No Vuelvas (Versión Cuarteto)                audio_features
# MERCHO                                          audio_features
# Cupido                                          audio_features
# Rara Vez                                        audio_features
# Yandel 150                                      audio_features
# Pobre Corazón                                   audio_features
# Arcángel: Bzrp Music Sessions, Vol. 54          audio_features
# Te Escapas De Mis Brazos (Remix)                audio_features
# Muñecas                                         audio_features
# Shakira: Bzrp Music Sessions, Vol. 53           audio_features
# Pa’ la Selección                                audio_features
# Quiero Creer                                    audio_features
# PUNTO G                                         audio_features
# Marisola - Remix                                audio_features
# Hey Mor                                         audio_features
# La Bachata                                      audio_features
# Coco Chanel                                     audio_features
# Feliz Cumpleaños Ferxxo                         audio_features
# Vida Gangster                                   audio_features
# Sesión - 6                                      audio_features
# Milagrosa                                       audio_features
# PLAYA DEL INGLÉS                                audio_features
# Dos Besitos                                     audio_features
# Si No Te Tengo / Ángel / Aquello Que Pasó       audio_features
# Tu Turrito                                      audio_features
# Costumbres - Vivo                               audio_features
# ARRANCARMELO                                    audio_features
# Quevedo: Bzrp Music Sessions, Vol. 52           audio_features
# CHORRITO PA LAS ANIMAS                          audio_features
# CALLEJERO FINO | DJ TAO Turreo Sessions #723    audio_features
# Amanecemos                                      audio_features
# Normal                                          audio_features
# Flowers                                         audio_features
# Le doy perreo                                   audio_features
# Butakera                                        audio_features
# ADIÓS                                           audio_features
# VISTA AL MAR                                    audio_features
# LA NENA DE ARGENTINA                            audio_features
# Universo Paralelo                               audio_features
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix  audio_features
# WANDA                                           audio_features
# DISCOTEKA (feat. Locura Mix)                    audio_features
# BESO                                            audio_features
# Que Te Vaya Bien                                audio_features
# El Merengue                                     audio_features
# MORNING                                         audio_features
# Te Mentiría                                     audio_features
#
#                                                                     id  \
# En La Intimidad | CROSSOVER #1                  7w7BrPbOjF5OxChs2dxFve
# M.A (Mejores Amigos)                            1eIDsKCLwZF6CJK8pOgHX5
# TQG                                             0DWdj2oZMBFSzRsi2Cvfzf
# Ya No Vuelvas (Versión Cuarteto)                6jRZ33ifS5VOTMwmPxhPhN
# MERCHO                                          1DxEbt6OSbrkRthk6pjZue
# Cupido                                          04ndZkbKGthTgYSv3xS7en
# Rara Vez                                        7MVIfkyzuUmQ716j8U7yGR
# Yandel 150                                      4FAKtPVycI4DxoOHC01YqD
# Pobre Corazón                                   1gpayq8BQ8Z1AZSCHUeZOC
# Arcángel: Bzrp Music Sessions, Vol. 54          7cQ0LAxT5HHCLGbxcjaxac
# Te Escapas De Mis Brazos (Remix)                6Vp8EcHAHjC9u7Qnsn2kob
# Muñecas                                         4yPmTUkWmUfLPQLCccp0DR
# Shakira: Bzrp Music Sessions, Vol. 53           4nrPB8O7Y7wsOCJdgXkthe
# Pa’ la Selección                                4J1vAbtAhMdsdpO1sKU3EO
# Quiero Creer                                    7HdEUquZzUzPjgSllvlJGl
# PUNTO G                                         4WiQA1AGWHFvaxBU6bHghs
# Marisola - Remix                                0NO2zL0kw8sGGnaMvHKAZF
# Hey Mor                                         1zsPaEkglFvxjAhrM8yhpr
# La Bachata                                      3tt9i3Hhzq84dPS8H7iSiJ
# Coco Chanel                                     0PB0O24JqAuNdOAFVJljMS
# Feliz Cumpleaños Ferxxo                         2CeKVsFFXG4QzA415QygGb
# Vida Gangster                                   4I4FFtKZLtyqw4he9pPtL7
# Sesión - 6                                      5sMcmy7UVizJoSm9YNZFyZ
# Milagrosa                                       4CVhywni3QwalKLZgwFi58
# PLAYA DEL INGLÉS                                0Sfn2TYbpQtCGMBf6C0Y6T
# Dos Besitos                                     4qXWX3OmEKp0YCnnxJqTMO
# Si No Te Tengo / Ángel / Aquello Que Pasó       1fKFxmSByZfjwVSbq0PHye
# Tu Turrito                                      45dlaEXrXW47TVbrQ4gK7E
# Costumbres - Vivo                               6HT88WDVwEJiHEbPuQ5XcB
# ARRANCARMELO                                    2x8oBuYaObjqHqgGuIUZ0b
# Quevedo: Bzrp Music Sessions, Vol. 52           2tTmW7RDtMQtBk7m2rYeSw
# CHORRITO PA LAS ANIMAS                          0CYTGMBYkwUxrj1MWDLrC5
# CALLEJERO FINO | DJ TAO Turreo Sessions #723    3fUZbg31mIJKIxuv8nUcGg
# Amanecemos                                      4L6PEEISI0EWoKh8Wwtvuh
# Normal                                          0T2pB7P1VdXPhLdQZ488uH
# Flowers                                         4DHcnVTT87F0zZhRPYmZ3B
# Le doy perreo                                   1DTmxMoV47mkuTrSY2xkyl
# Butakera                                        60DHrnRAhNJMy4WeEf23NH
# ADIÓS                                           2bNCiY24Eh4saMcc23bvUN
# VISTA AL MAR                                    5q86iSKkBtOoNkdgEDY5WV
# LA NENA DE ARGENTINA                            0Dl34Kegtc0y0m0oPhQfiI
# Universo Paralelo                               6LBpjWMfy1NUfyxAJbcMRs
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix  4IkSOwB9JRhq7oScl4pCW9
# WANDA                                           0Iozrbed8spxoBnmtBMshO
# DISCOTEKA (feat. Locura Mix)                    5w7RsSgxxBwdVTSyQDj8Bi
# BESO                                            609E1JCInJncactoMmkDon
# Que Te Vaya Bien                                3sfgK7baHGsEAiZjTOtWrz
# El Merengue                                     51FvjPEGKq2zByeeEQ43V9
# MORNING                                         1dJhW3HRdLnySFEUhf6VRh
# Te Mentiría                                     3EcCc1U405tm8yKm1x6Y8W
#
#                                                                                  uri  \
# En La Intimidad | CROSSOVER #1                  spotify:track:7w7BrPbOjF5OxChs2dxFve
# M.A (Mejores Amigos)                            spotify:track:1eIDsKCLwZF6CJK8pOgHX5
# TQG                                             spotify:track:0DWdj2oZMBFSzRsi2Cvfzf
# Ya No Vuelvas (Versión Cuarteto)                spotify:track:6jRZ33ifS5VOTMwmPxhPhN
# MERCHO                                          spotify:track:1DxEbt6OSbrkRthk6pjZue
# Cupido                                          spotify:track:04ndZkbKGthTgYSv3xS7en
# Rara Vez                                        spotify:track:7MVIfkyzuUmQ716j8U7yGR
# Yandel 150                                      spotify:track:4FAKtPVycI4DxoOHC01YqD
# Pobre Corazón                                   spotify:track:1gpayq8BQ8Z1AZSCHUeZOC
# Arcángel: Bzrp Music Sessions, Vol. 54          spotify:track:7cQ0LAxT5HHCLGbxcjaxac
# Te Escapas De Mis Brazos (Remix)                spotify:track:6Vp8EcHAHjC9u7Qnsn2kob
# Muñecas                                         spotify:track:4yPmTUkWmUfLPQLCccp0DR
# Shakira: Bzrp Music Sessions, Vol. 53           spotify:track:4nrPB8O7Y7wsOCJdgXkthe
# Pa’ la Selección                                spotify:track:4J1vAbtAhMdsdpO1sKU3EO
# Quiero Creer                                    spotify:track:7HdEUquZzUzPjgSllvlJGl
# PUNTO G                                         spotify:track:4WiQA1AGWHFvaxBU6bHghs
# Marisola - Remix                                spotify:track:0NO2zL0kw8sGGnaMvHKAZF
# Hey Mor                                         spotify:track:1zsPaEkglFvxjAhrM8yhpr
# La Bachata                                      spotify:track:3tt9i3Hhzq84dPS8H7iSiJ
# Coco Chanel                                     spotify:track:0PB0O24JqAuNdOAFVJljMS
# Feliz Cumpleaños Ferxxo                         spotify:track:2CeKVsFFXG4QzA415QygGb
# Vida Gangster                                   spotify:track:4I4FFtKZLtyqw4he9pPtL7
# Sesión - 6                                      spotify:track:5sMcmy7UVizJoSm9YNZFyZ
# Milagrosa                                       spotify:track:4CVhywni3QwalKLZgwFi58
# PLAYA DEL INGLÉS                                spotify:track:0Sfn2TYbpQtCGMBf6C0Y6T
# Dos Besitos                                     spotify:track:4qXWX3OmEKp0YCnnxJqTMO
# Si No Te Tengo / Ángel / Aquello Que Pasó       spotify:track:1fKFxmSByZfjwVSbq0PHye
# Tu Turrito                                      spotify:track:45dlaEXrXW47TVbrQ4gK7E
# Costumbres - Vivo                               spotify:track:6HT88WDVwEJiHEbPuQ5XcB
# ARRANCARMELO                                    spotify:track:2x8oBuYaObjqHqgGuIUZ0b
# Quevedo: Bzrp Music Sessions, Vol. 52           spotify:track:2tTmW7RDtMQtBk7m2rYeSw
# CHORRITO PA LAS ANIMAS                          spotify:track:0CYTGMBYkwUxrj1MWDLrC5
# CALLEJERO FINO | DJ TAO Turreo Sessions #723    spotify:track:3fUZbg31mIJKIxuv8nUcGg
# Amanecemos                                      spotify:track:4L6PEEISI0EWoKh8Wwtvuh
# Normal                                          spotify:track:0T2pB7P1VdXPhLdQZ488uH
# Flowers                                         spotify:track:4DHcnVTT87F0zZhRPYmZ3B
# Le doy perreo                                   spotify:track:1DTmxMoV47mkuTrSY2xkyl
# Butakera                                        spotify:track:60DHrnRAhNJMy4WeEf23NH
# ADIÓS                                           spotify:track:2bNCiY24Eh4saMcc23bvUN
# VISTA AL MAR                                    spotify:track:5q86iSKkBtOoNkdgEDY5WV
# LA NENA DE ARGENTINA                            spotify:track:0Dl34Kegtc0y0m0oPhQfiI
# Universo Paralelo                               spotify:track:6LBpjWMfy1NUfyxAJbcMRs
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix  spotify:track:4IkSOwB9JRhq7oScl4pCW9
# WANDA                                           spotify:track:0Iozrbed8spxoBnmtBMshO
# DISCOTEKA (feat. Locura Mix)                    spotify:track:5w7RsSgxxBwdVTSyQDj8Bi
# BESO                                            spotify:track:609E1JCInJncactoMmkDon
# Que Te Vaya Bien                                spotify:track:3sfgK7baHGsEAiZjTOtWrz
# El Merengue                                     spotify:track:51FvjPEGKq2zByeeEQ43V9
# MORNING                                         spotify:track:1dJhW3HRdLnySFEUhf6VRh
# Te Mentiría                                     spotify:track:3EcCc1U405tm8yKm1x6Y8W
#
#                                                                                        track_href  \
# En La Intimidad | CROSSOVER #1                  https://api.spotify.com/v1/tracks/7w7BrPbOjF5O...
# M.A (Mejores Amigos)                            https://api.spotify.com/v1/tracks/1eIDsKCLwZF6...
# TQG                                             https://api.spotify.com/v1/tracks/0DWdj2oZMBFS...
# Ya No Vuelvas (Versión Cuarteto)                https://api.spotify.com/v1/tracks/6jRZ33ifS5VO...
# MERCHO                                          https://api.spotify.com/v1/tracks/1DxEbt6OSbrk...
# Cupido                                          https://api.spotify.com/v1/tracks/04ndZkbKGthT...
# Rara Vez                                        https://api.spotify.com/v1/tracks/7MVIfkyzuUmQ...
# Yandel 150                                      https://api.spotify.com/v1/tracks/4FAKtPVycI4D...
# Pobre Corazón                                   https://api.spotify.com/v1/tracks/1gpayq8BQ8Z1...
# Arcángel: Bzrp Music Sessions, Vol. 54          https://api.spotify.com/v1/tracks/7cQ0LAxT5HHC...
# Te Escapas De Mis Brazos (Remix)                https://api.spotify.com/v1/tracks/6Vp8EcHAHjC9...
# Muñecas                                         https://api.spotify.com/v1/tracks/4yPmTUkWmUfL...
# Shakira: Bzrp Music Sessions, Vol. 53           https://api.spotify.com/v1/tracks/4nrPB8O7Y7ws...
# Pa’ la Selección                                https://api.spotify.com/v1/tracks/4J1vAbtAhMds...
# Quiero Creer                                    https://api.spotify.com/v1/tracks/7HdEUquZzUzP...
# PUNTO G                                         https://api.spotify.com/v1/tracks/4WiQA1AGWHFv...
# Marisola - Remix                                https://api.spotify.com/v1/tracks/0NO2zL0kw8sG...
# Hey Mor                                         https://api.spotify.com/v1/tracks/1zsPaEkglFvx...
# La Bachata                                      https://api.spotify.com/v1/tracks/3tt9i3Hhzq84...
# Coco Chanel                                     https://api.spotify.com/v1/tracks/0PB0O24JqAuN...
# Feliz Cumpleaños Ferxxo                         https://api.spotify.com/v1/tracks/2CeKVsFFXG4Q...
# Vida Gangster                                   https://api.spotify.com/v1/tracks/4I4FFtKZLtyq...
# Sesión - 6                                      https://api.spotify.com/v1/tracks/5sMcmy7UVizJ...
# Milagrosa                                       https://api.spotify.com/v1/tracks/4CVhywni3Qwa...
# PLAYA DEL INGLÉS                                https://api.spotify.com/v1/tracks/0Sfn2TYbpQtC...
# Dos Besitos                                     https://api.spotify.com/v1/tracks/4qXWX3OmEKp0...
# Si No Te Tengo / Ángel / Aquello Que Pasó       https://api.spotify.com/v1/tracks/1fKFxmSByZfj...
# Tu Turrito                                      https://api.spotify.com/v1/tracks/45dlaEXrXW47...
# Costumbres - Vivo                               https://api.spotify.com/v1/tracks/6HT88WDVwEJi...
# ARRANCARMELO                                    https://api.spotify.com/v1/tracks/2x8oBuYaObjq...
# Quevedo: Bzrp Music Sessions, Vol. 52           https://api.spotify.com/v1/tracks/2tTmW7RDtMQt...
# CHORRITO PA LAS ANIMAS                          https://api.spotify.com/v1/tracks/0CYTGMBYkwUx...
# CALLEJERO FINO | DJ TAO Turreo Sessions #723    https://api.spotify.com/v1/tracks/3fUZbg31mIJK...
# Amanecemos                                      https://api.spotify.com/v1/tracks/4L6PEEISI0EW...
# Normal                                          https://api.spotify.com/v1/tracks/0T2pB7P1VdXP...
# Flowers                                         https://api.spotify.com/v1/tracks/4DHcnVTT87F0...
# Le doy perreo                                   https://api.spotify.com/v1/tracks/1DTmxMoV47mk...
# Butakera                                        https://api.spotify.com/v1/tracks/60DHrnRAhNJM...
# ADIÓS                                           https://api.spotify.com/v1/tracks/2bNCiY24Eh4s...
# VISTA AL MAR                                    https://api.spotify.com/v1/tracks/5q86iSKkBtOo...
# LA NENA DE ARGENTINA                            https://api.spotify.com/v1/tracks/0Dl34Kegtc0y...
# Universo Paralelo                               https://api.spotify.com/v1/tracks/6LBpjWMfy1NU...
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix  https://api.spotify.com/v1/tracks/4IkSOwB9JRhq...
# WANDA                                           https://api.spotify.com/v1/tracks/0Iozrbed8spx...
# DISCOTEKA (feat. Locura Mix)                    https://api.spotify.com/v1/tracks/5w7RsSgxxBwd...
# BESO                                            https://api.spotify.com/v1/tracks/609E1JCInJnc...
# Que Te Vaya Bien                                https://api.spotify.com/v1/tracks/3sfgK7baHGsE...
# El Merengue                                     https://api.spotify.com/v1/tracks/51FvjPEGKq2z...
# MORNING                                         https://api.spotify.com/v1/tracks/1dJhW3HRdLny...
# Te Mentiría                                     https://api.spotify.com/v1/tracks/3EcCc1U405tm...
#
#                                                                                      analysis_url  \
# En La Intimidad | CROSSOVER #1                  https://api.spotify.com/v1/audio-analysis/7w7B...
# M.A (Mejores Amigos)                            https://api.spotify.com/v1/audio-analysis/1eID...
# TQG                                             https://api.spotify.com/v1/audio-analysis/0DWd...
# Ya No Vuelvas (Versión Cuarteto)                https://api.spotify.com/v1/audio-analysis/6jRZ...
# MERCHO                                          https://api.spotify.com/v1/audio-analysis/1DxE...
# Cupido                                          https://api.spotify.com/v1/audio-analysis/04nd...
# Rara Vez                                        https://api.spotify.com/v1/audio-analysis/7MVI...
# Yandel 150                                      https://api.spotify.com/v1/audio-analysis/4FAK...
# Pobre Corazón                                   https://api.spotify.com/v1/audio-analysis/1gpa...
# Arcángel: Bzrp Music Sessions, Vol. 54          https://api.spotify.com/v1/audio-analysis/7cQ0...
# Te Escapas De Mis Brazos (Remix)                https://api.spotify.com/v1/audio-analysis/6Vp8...
# Muñecas                                         https://api.spotify.com/v1/audio-analysis/4yPm...
# Shakira: Bzrp Music Sessions, Vol. 53           https://api.spotify.com/v1/audio-analysis/4nrP...
# Pa’ la Selección                                https://api.spotify.com/v1/audio-analysis/4J1v...
# Quiero Creer                                    https://api.spotify.com/v1/audio-analysis/7HdE...
# PUNTO G                                         https://api.spotify.com/v1/audio-analysis/4WiQ...
# Marisola - Remix                                https://api.spotify.com/v1/audio-analysis/0NO2...
# Hey Mor                                         https://api.spotify.com/v1/audio-analysis/1zsP...
# La Bachata                                      https://api.spotify.com/v1/audio-analysis/3tt9...
# Coco Chanel                                     https://api.spotify.com/v1/audio-analysis/0PB0...
# Feliz Cumpleaños Ferxxo                         https://api.spotify.com/v1/audio-analysis/2CeK...
# Vida Gangster                                   https://api.spotify.com/v1/audio-analysis/4I4F...
# Sesión - 6                                      https://api.spotify.com/v1/audio-analysis/5sMc...
# Milagrosa                                       https://api.spotify.com/v1/audio-analysis/4CVh...
# PLAYA DEL INGLÉS                                https://api.spotify.com/v1/audio-analysis/0Sfn...
# Dos Besitos                                     https://api.spotify.com/v1/audio-analysis/4qXW...
# Si No Te Tengo / Ángel / Aquello Que Pasó       https://api.spotify.com/v1/audio-analysis/1fKF...
# Tu Turrito                                      https://api.spotify.com/v1/audio-analysis/45dl...
# Costumbres - Vivo                               https://api.spotify.com/v1/audio-analysis/6HT8...
# ARRANCARMELO                                    https://api.spotify.com/v1/audio-analysis/2x8o...
# Quevedo: Bzrp Music Sessions, Vol. 52           https://api.spotify.com/v1/audio-analysis/2tTm...
# CHORRITO PA LAS ANIMAS                          https://api.spotify.com/v1/audio-analysis/0CYT...
# CALLEJERO FINO | DJ TAO Turreo Sessions #723    https://api.spotify.com/v1/audio-analysis/3fUZ...
# Amanecemos                                      https://api.spotify.com/v1/audio-analysis/4L6P...
# Normal                                          https://api.spotify.com/v1/audio-analysis/0T2p...
# Flowers                                         https://api.spotify.com/v1/audio-analysis/4DHc...
# Le doy perreo                                   https://api.spotify.com/v1/audio-analysis/1DTm...
# Butakera                                        https://api.spotify.com/v1/audio-analysis/60DH...
# ADIÓS                                           https://api.spotify.com/v1/audio-analysis/2bNC...
# VISTA AL MAR                                    https://api.spotify.com/v1/audio-analysis/5q86...
# LA NENA DE ARGENTINA                            https://api.spotify.com/v1/audio-analysis/0Dl3...
# Universo Paralelo                               https://api.spotify.com/v1/audio-analysis/6LBp...
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix  https://api.spotify.com/v1/audio-analysis/4IkS...
# WANDA                                           https://api.spotify.com/v1/audio-analysis/0Ioz...
# DISCOTEKA (feat. Locura Mix)                    https://api.spotify.com/v1/audio-analysis/5w7R...
# BESO                                            https://api.spotify.com/v1/audio-analysis/609E...
# Que Te Vaya Bien                                https://api.spotify.com/v1/audio-analysis/3sfg...
# El Merengue                                     https://api.spotify.com/v1/audio-analysis/51Fv...
# MORNING                                         https://api.spotify.com/v1/audio-analysis/1dJh...
# Te Mentiría                                     https://api.spotify.com/v1/audio-analysis/3EcC...
#
#                                                 duration_ms  time_signature
# En La Intimidad | CROSSOVER #1                       172118               4
# M.A (Mejores Amigos)                                 158310               4
# TQG                                                  199440               4
# Ya No Vuelvas (Versión Cuarteto)                     204000               4
# MERCHO                                               161452               4
# Cupido                                               174370               4
# Rara Vez                                             128677               4
# Yandel 150                                           216148               4
# Pobre Corazón                                        198931               4
# Arcángel: Bzrp Music Sessions, Vol. 54               228387               4
# Te Escapas De Mis Brazos (Remix)                     217826               4
# Muñecas                                              156319               4
# Shakira: Bzrp Music Sessions, Vol. 53                218289               4
# Pa’ la Selección                                     186735               4
# Quiero Creer                                         145055               3
# PUNTO G                                              151325               4
# Marisola - Remix                                     237474               4
# Hey Mor                                              196600               4
# La Bachata                                           162638               4
# Coco Chanel                                          160325               4
# Feliz Cumpleaños Ferxxo                              155960               4
# Vida Gangster                                        170058               4
# Sesión - 6                                           150316               4
# Milagrosa                                            140288               4
# PLAYA DEL INGLÉS                                     237525               4
# Dos Besitos                                          149083               4
# Si No Te Tengo / Ángel / Aquello Que Pasó            428439               4
# Tu Turrito                                           164701               4
# Costumbres - Vivo                                    133077               4
# ARRANCARMELO                                         183547               4
# Quevedo: Bzrp Music Sessions, Vol. 52                198938               4
# CHORRITO PA LAS ANIMAS                               168133               4
# CALLEJERO FINO | DJ TAO Turreo Sessions #723         163260               4
# Amanecemos                                           198183               4
# Normal                                               171880               4
# Flowers                                              200455               4
# Le doy perreo                                        138980               4
# Butakera                                             143402               4
# ADIÓS                                                160856               4
# VISTA AL MAR                                         180673               4
# LA NENA DE ARGENTINA                                 151988               4
# Universo Paralelo                                    217072               4
# ¿Y pa la Wacha Loca? (con Salastkbron) - Remix       229426               4
# WANDA                                                160909               4
# DISCOTEKA (feat. Locura Mix)                         204481               4
# BESO                                                 194543               4
# Que Te Vaya Bien                                     124238               4
# El Merengue                                          189357               4
# MORNING                                              122483               3
# Te Mentiría                                          218431               4

# %% [markdown]
# This dataframe shows the audio features of the most 50 popular songs in a country (in this case Argentina). Since we know the audio features of the most popular songs, we could take the mean value of all these audio features and put it into a dataframe. We can use it as a representation of what music the country's users like to listen to.<br><br> Then afterwards we could join all the dataframes together to show what kind of music the users of each country like to listen to.

# %%
df_argentina.mean()
# Out:
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/182284860.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_argentina.mean()
# danceability             0.738700
# energy                   0.665500
# key                      5.780000
# loudness                -5.244980
# mode                     0.440000
# speechiness              0.115564
# acousticness             0.237986
# instrumentalness         0.003264
# liveness                 0.212630
# valence                  0.633600
# tempo                  112.972900
# duration_ms         182502.020000
# time_signature           3.960000
# dtype: float64

# %% [markdown]
# Using the method .mean() on this dataframe returns a panda series with the mean value of each audio feature. We can convert this series into a dataframe and then transpose it so that the audio features are the columns and the mean values are the rows. This will make it easier to join all the dataframes together later.

# %%
# getting the mean value of the features for each country's playlist
# and then putting them into a list of dataframes
# to be concatenated into one dataframe
# using list comprehension to make the code more efficient
list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
df_all_audio_features = pd.concat(list_of_dfs)
df_all_audio_features
# Out:
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
# /var/folders/c_/lwvsxwd94kv4bvh2zjvgt3rc0000gn/T/ipykernel_829/2352057950.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   list_of_dfs = [(get_features(top_50_playlists[i]).mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
#                 danceability   energy   key  loudness  mode  speechiness  \
# Argentina            0.73870  0.66550  5.78  -5.24498  0.44     0.115564
# Australia            0.65956  0.64192  5.22  -6.50540  0.74     0.082410
# Austria              0.73002  0.69158  4.70  -6.51260  0.46     0.119706
# Belarus              0.64810  0.68016  5.10  -6.91520  0.48     0.131206
# Belgium              0.65772  0.67340  4.36  -6.50024  0.62     0.088458
# ...                      ...      ...   ...       ...   ...          ...
# United Kingdom       0.65424  0.66520  5.12  -6.37802  0.64     0.092536
# United States        0.63610  0.62284  5.38  -6.76924  0.54     0.090490
# Uruguay              0.74848  0.65648  5.62  -5.34632  0.36     0.127354
# Venezuela            0.76312  0.66604  4.70  -5.12824  0.36     0.141096
# Vietnam              0.67386  0.52996  5.02  -8.40792  0.62     0.072794
#
#                 acousticness  instrumentalness  liveness   valence      tempo  \
# Argentina           0.237986          0.003264  0.212630  0.633600  112.97290
# Australia           0.250339          0.019363  0.163216  0.521600  123.13682
# Austria             0.235949          0.012272  0.201260  0.583780  126.87928
# Belarus             0.178967          0.067352  0.219444  0.477620  135.23300
# Belgium             0.227131          0.020708  0.162494  0.514760  123.57646
# ...                      ...               ...       ...       ...        ...
# United Kingdom      0.237688          0.021773  0.167094  0.524620  123.45104
# United States       0.278944          0.010649  0.181414  0.479802  128.33966
# Uruguay             0.249608          0.016663  0.162648  0.649060  116.12322
# Venezuela           0.259639          0.017289  0.166628  0.551980  121.62506
# Vietnam             0.503014          0.021838  0.168456  0.447876  129.17314
#
#                 duration_ms  time_signature
# Argentina         182502.02            3.96
# Australia         195127.40            3.86
# Austria           176379.08            4.00
# Belarus           152813.96            3.92
# Belgium           192922.48            3.98
# ...                     ...             ...
# United Kingdom    195303.12            3.96
# United States     196193.46            3.78
# Uruguay           179966.12            3.92
# Venezuela         192730.20            3.98
# Vietnam           210882.22            3.90
#
# [72 rows x 13 columns]

# %% [markdown]
# Now we will clean the data by choosing only the columns that are of interest to us. By using .mean() earlier, we have already gotten rid of columns like track id or analysis_url as they are strings. We can also get rid of columns like time_signature and key because they are not that different between countries.

# %%
# I'm only interested in these features because there is a noticeable variation in the values across countries
interested_features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 
                       'liveness', 'valence', 'tempo']
# making another dataframe to show only the features I'm interested in
list_of_dfs = [(get_features(top_50_playlists[i])[interested_features].mean().rename(top_50_playlists[i]['country']).to_frame().swapaxes('index', 'columns')) for i in range(len(top_50_playlists))]
df_audio_features = pd.concat(list_of_dfs)
df_audio_features
# Out:
#                 danceability   energy  loudness  speechiness  acousticness  \
# Argentina            0.73870  0.66550  -5.24498     0.115564      0.237986
# Australia            0.65956  0.64192  -6.50540     0.082410      0.250339
# Austria              0.73002  0.69158  -6.51260     0.119706      0.235949
# Belarus              0.64810  0.68016  -6.91520     0.131206      0.178967
# Belgium              0.65772  0.67340  -6.50024     0.088458      0.227131
# ...                      ...      ...       ...          ...           ...
# United Kingdom       0.65424  0.66520  -6.37802     0.092536      0.237688
# United States        0.63610  0.62284  -6.76924     0.090490      0.278944
# Uruguay              0.74848  0.65648  -5.34632     0.127354      0.249608
# Venezuela            0.76312  0.66604  -5.12824     0.141096      0.259639
# Vietnam              0.67386  0.52996  -8.40792     0.072794      0.503014
#
#                 instrumentalness  liveness   valence      tempo
# Argentina               0.003264  0.212630  0.633600  112.97290
# Australia               0.019363  0.163216  0.521600  123.13682
# Austria                 0.012272  0.201260  0.583780  126.87928
# Belarus                 0.067352  0.219444  0.477620  135.23300
# Belgium                 0.020708  0.162494  0.514760  123.57646
# ...                          ...       ...       ...        ...
# United Kingdom          0.021773  0.167094  0.524620  123.45104
# United States           0.010649  0.181414  0.479802  128.33966
# Uruguay                 0.016663  0.162648  0.649060  116.12322
# Venezuela               0.017289  0.166628  0.551980  121.62506
# Vietnam                 0.021838  0.168456  0.447876  129.17314
#
# [72 rows x 9 columns]

# %% [markdown]
# Just at first glance there are some fun trends (eg. the Latin American countries like to listen to songs with higher danceability). But I'm not sure how to plot this data. Maybe someone could provide some suggestions?

# %%
import plotnine as p9

# creating a scatterplot to see danceability vs valence (perceived happiness of a song)
scatterplot = p9.ggplot(data=df_audio_features,
                     mapping=p9.aes(x='danceability', y='valence', )) + p9.geom_point() + p9.geom_smooth(method='lm')

scatterplot
# Out:
# <ggplot: (279226140)>

# %%
countries = df_audio_features.index.tolist()
countries
# Out:
# ['Argentina',
#  'Australia',
#  'Austria',
#  'Belarus',
#  'Belgium',
#  'Bolivia',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Guatemala',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Kazakhstan',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malaysia',
#  'Mexico',
#  'Morocco',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Nigeria',
#  'Norway',
#  'Pakistan',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Saudi Arabia',
#  'Singapore',
#  'Slovakia',
#  'South Africa',
#  'South Korea',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Thailand',
#  'Turkey',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Venezuela',
#  'Vietnam']

# %%
# assigning regions to each country so we can have a regional look at the data
regions = ['South America', 
           'Oceania', 
           'Central Europe',
           'Eastern Europe',
           'Western Europe', 
           'South America',
           'South America',
           'Eastern Europe',
           'North America',
           'South America',
           'South America',
           'Central America',
           'Central Europe',
           'Northern Europe', 
           'Central America',
           'South America',
           'Middle East',
           'Central America',
           'Northern Europe', 
           'Northern Europe', 
           'Western Europe',
           'Central Europe',
           'Southern Europe',
           'Central America',
           'Central America',
           'Northeast Asia',
           'Central Europe', 
           'Northern Europe',
           'South Asia',
           'Southeast Asia',
           'Western Europe',
           'Middle East',
           'Southern Europe',
           'Northeast Asia',
           'Eastern Europe',
           'Northern Europe',
           'Northern Europe',
           'Western Europe',
           'Southeast Asia',
           'North America',
           'Africa',
           'Western Europe',
           'Oceania',
           'Central America',
           'Africa',
           'Northern Europe',
           'South Asia',
           'Central America',
           'South America',
           'South America',
           'Southeast Asia',
           'Central Europe',
           'Southern Europe',
           'Eastern Europe',
           'Middle East',
           'Southeast Asia',
           'Central Europe',
           'Africa',
           'Northeast Asia',
           'Southern Europe',
           'Northern Europe',
           'Central Europe',
           'Northeast Asia',
           'Southeast Asia',
           'Southern Europe',
           'Eastern Europe',
           'Middle East',
           'Western Europe',
           'North America',
           'South America',
           'South America',
           'Southeast Asia']
len(regions)
# Out:
# 72

# %%
countries_and_regions = pd.DataFrame(regions, index = countries,
                                              columns =['region'])

# %%
countries_and_regions
# Out:
#                         region
# Argentina        South America
# Australia              Oceania
# Austria         Central Europe
# Belarus         Eastern Europe
# Belgium         Western Europe
# ...                        ...
# United Kingdom  Western Europe
# United States    North America
# Uruguay          South America
# Venezuela        South America
# Vietnam         Southeast Asia
#
# [72 rows x 1 columns]

# %%
df_audio_features_with_regions = countries_and_regions.join(df_audio_features)
df_audio_features_with_regions
# Out:
#                         region  danceability   energy  loudness  speechiness  \
# Argentina        South America       0.73870  0.66550  -5.24498     0.115564
# Australia              Oceania       0.65956  0.64192  -6.50540     0.082410
# Austria         Central Europe       0.73002  0.69158  -6.51260     0.119706
# Belarus         Eastern Europe       0.64810  0.68016  -6.91520     0.131206
# Belgium         Western Europe       0.65772  0.67340  -6.50024     0.088458
# ...                        ...           ...      ...       ...          ...
# United Kingdom  Western Europe       0.65424  0.66520  -6.37802     0.092536
# United States    North America       0.63610  0.62284  -6.76924     0.090490
# Uruguay          South America       0.74848  0.65648  -5.34632     0.127354
# Venezuela        South America       0.76312  0.66604  -5.12824     0.141096
# Vietnam         Southeast Asia       0.67386  0.52996  -8.40792     0.072794
#
#                 acousticness  instrumentalness  liveness   valence      tempo
# Argentina           0.237986          0.003264  0.212630  0.633600  112.97290
# Australia           0.250339          0.019363  0.163216  0.521600  123.13682
# Austria             0.235949          0.012272  0.201260  0.583780  126.87928
# Belarus             0.178967          0.067352  0.219444  0.477620  135.23300
# Belgium             0.227131          0.020708  0.162494  0.514760  123.57646
# ...                      ...               ...       ...       ...        ...
# United Kingdom      0.237688          0.021773  0.167094  0.524620  123.45104
# United States       0.278944          0.010649  0.181414  0.479802  128.33966
# Uruguay             0.249608          0.016663  0.162648  0.649060  116.12322
# Venezuela           0.259639          0.017289  0.166628  0.551980  121.62506
# Vietnam             0.503014          0.021838  0.168456  0.447876  129.17314
#
# [72 rows x 10 columns]

# %%
plot = (p9.ggplot(data=df_audio_features_with_regions,
           mapping=p9.aes(x='region',
                          y='danceability'))
        + p9.geom_jitter(alpha=0.2)
        + p9.geom_boxplot(alpha=0.)
        + p9.theme(axis_text_x=p9.element_text(rotation=90, hjust=1))
        )

plot
# Out:
# <ggplot: (307431722)>

# %% [markdown]
# ### Other ideas for further analysis: <br>
# - What are the most popular genres in each country? (by getting the genres that each artist in each country's top 50 playlist belongs to) <br>
# - Who are the most popular artists in each country? (basically seeing which artists appear in each country's top 50 playlist) <br>
# - I can also use the Spotify API to [get the related artists for each of these artists](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and then do some network analysis on that.

# %% [markdown]
# ### Limitations: <br>
# Spotify API has a rate limit of about 180 requests per minute [based on a rolling 30 second window](https://developer.spotify.com/documentation/web-api/guides/rate-limits/).
